# %%
import pandas as pd

geolocation_df = pd.read_csv("C:/Users/Ros/Desktop/JDC/finalproject/Dataset/olist_geolocation_dataset.csv")

geolocation_df.head(50)
# Out:
#     geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                          1037       -23.545621       -46.639292
# 1                          1046       -23.546081       -46.644820
# 2                          1046       -23.546129       -46.642951
# 3                          1041       -23.544392       -46.639499
# 4                          1035       -23.541578       -46.641607
# 5                          1012       -23.547762       -46.635361
# 6                          1047       -23.546273       -46.641225
# 7                          1013       -23.546923       -46.634264
# 8                          1029       -23.543769       -46.634278
# 9                          1011       -23.547640       -46.636032
# 10                         1013       -23.547325       -46.634184
# 11                         1032       -23.538418       -46.634778
# 12                         1014       -23.546435       -46.633830
# 13                         1012       -23.548946       -46.634671
# 14                         1037       -23.545187       -46.637855
# 15                         1046       -23.546081       -46.644820
# 16                         1039       -23.541883       -46.639919
# 17                         1024       -23.541390       -46.629899
# 18                         1009       -23.546935       -46.636588
# 19                         1046       -23.545884       -46.643163
# 20                         1046       -23.545166       -46.643786
# 21                         1020       -23.552235       -46.628441
# 22                         1011       -23.546690       -46.635447
# 23                         1043       -23.546657       -46.640788
# 24                         1050       -23.549774       -46.645599
# 25                         1045       -23.541594       -46.641894
# 26                         1009       -23.545430       -46.635715
# 27                         1007       -23.550393       -46.637302
# 28                         1032       -23.539842       -46.635148
# 29                         1041       -23.543539       -46.640577
# 30                         1005       -23.549819       -46.635606
# 31                         1037       -23.546705       -46.640336
# 32                         1017       -23.550011       -46.631166
# 33                         1046       -23.545320       -46.644069
# 34                         1019       -23.552152       -46.630802
# 35                         1032       -23.540775       -46.635515
# 36                         1017       -23.549295       -46.632075
# 37                         1050       -23.549009       -46.642812
# 38                         1050       -23.548756       -46.642789
# 39                         1027       -23.538301       -46.630764
# 40                         1050       -23.549854       -46.643139
# 41                         1013       -23.547119       -46.634233
# 42                         1033       -23.540321       -46.636395
# 43                         1009       -23.545692       -46.635866
# 44                         1046       -23.546081       -46.644820
# 45                         1050       -23.548748       -46.642391
# 46                         1032       -23.541191       -46.634993
# 47                         1020       -23.552549       -46.631632
# 48                         1006       -23.550524       -46.636694
# 49                         1034       -23.542392       -46.637709
#
#    geolocation_city geolocation_state
# 0         sao paulo                SP
# 1         sao paulo                SP
# 2         sao paulo                SP
# 3         sao paulo                SP
# 4         sao paulo                SP
# 5         são paulo                SP
# 6         sao paulo                SP
# 7         sao paulo                SP
# 8         sao paulo                SP
# 9         sao paulo                SP
# 10        sao paulo                SP
# 11        sao paulo                SP
# 12        sao paulo                SP
# 13        sao paulo                SP
# 14        são paulo                SP
# 15        sao paulo                SP
# 16        sao paulo                SP
# 17        são paulo                SP
# 18        sao paulo                SP
# 19        sao paulo                SP
# 20        sao paulo                SP
# 21        são paulo                SP
# 22        são paulo                SP
# 23        são paulo                SP
# 24        sao paulo                SP
# 25        sao paulo                SP
# 26        sao paulo                SP
# 27        sao paulo                SP
# 28        são paulo                SP
# 29        sao paulo                SP
# 30        sao paulo                SP
# 31        são paulo                SP
# 32        são paulo                SP
# 33        sao paulo                SP
# 34        sao paulo                SP
# 35        sao paulo                SP
# 36        sao paulo                SP
# 37        sao paulo                SP
# 38        sao paulo                SP
# 39        sao paulo                SP
# 40        sao paulo                SP
# 41        sao paulo                SP
# 42        sao paulo                SP
# 43        sao paulo                SP
# 44        sao paulo                SP
# 45        sao paulo                SP
# 46        sao paulo                SP
# 47        sao paulo                SP
# 48        sao paulo                SP
# 49        sao paulo                SP

# %% [markdown]
# checking the data types in each column

# %%
geolocation_df.dtypes
# Out:
# geolocation_zip_code_prefix      int64
# geolocation_lat                float64
# geolocation_lng                float64
# geolocation_city                object
# geolocation_state               object
# dtype: object

# %% [markdown]
# Printing a concise summary of a DataFrame.

# %%
geolocation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %% [markdown]
# there are no null values.

# %%
geolocation_df.describe() #to find the summery statistics
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %% [markdown]
# Brazils most Northern spot is at 5 deg 16′ 27.8″ N latitude.So converting to Decimal Degree,it will be 5.27222222. latitude of South is 33 Deg 44'32", ie 33.74222222 DD. Eastern spot is at 34 degree 47'30", ie 34.79166666 DD.Western spot is at 73Degree 59'32", ie 73.99222055

# %%
#Brazils most Northern spot is at 5 deg 16′ 27.8″ N latitude
geolocation_df = geolocation_df[geolocation_df.geolocation_lat <= 5.2722222]
#it’s most Western spot is at 73 deg, 59′ 32″W Long.
geolocation_df = geolocation_df[geolocation_df.geolocation_lng >= -73.99222055]
#It’s most southern spot is at 33 deg, 44′ 32″ S Latitude.
geolocation_df = geolocation_df[geolocation_df.geolocation_lat >= -33.74222222]
#It’s most Eastern spot is 34 deg, 47′ 30″ W Long.
geolocation_df = geolocation_df[geolocation_df.geolocation_lng <=  -34.79166666]

# %%
geolocation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000121 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000121 non-null  int64
#  1   geolocation_lat              1000121 non-null  float64
#  2   geolocation_lng              1000121 non-null  float64
#  3   geolocation_city             1000121 non-null  object
#  4   geolocation_state            1000121 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 45.8+ MB

# %%
unique_cities=geolocation_df['geolocation_city'].unique()
unique_cities
# Out:
# array(['sao paulo', 'são paulo', 'sao bernardo do campo', ..., 'ciríaco',
#        'estação', 'vila lângaro'], dtype=object)

# %%
#replacing special characters
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('são', 'sao', case=False)

# %%
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('sa£o', 'sao', case=False)

# %%
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('saopaulo', 'sao paulo', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('sp', 'sao paulo', case=False)

# %%
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('embu-guacu', 'embu guacu', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('embu-guaçu', 'embu guacu', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('embu guaçu', 'embu guacu', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('embuguacu', 'embu guacu', case=False)

# %%
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('carapicuíba', 'carapicuiba', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('santana de parnaíba', 'santana de parnaiba', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('sao lourenço da serra', 'sao lourenco da serra', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('á','a', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('é', 'e', case=False)

# %%
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('ç', 'c', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('ã', 'a', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('í','i', case=False)

# %%
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('â','a', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('ó','o', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('ú','u', case=False)

# %%
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('-',' ', case=False)

geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('ô','o', case=False)

# %%
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('4º centenario', 'centenario', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('4o. centenario', 'centenario', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('ê', 'e', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('´t', 't', case=False)

# %%
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('alcantaras', 'alcantara', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('agudos', 'agudo', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('* cidade', 'cidade', case=False)

# %%
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('...arraial do cabo', 'arraial do cabo', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('alta floresta do oeste', 'alta floresta d-oeste', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('alta floresta doeste', 'alta floresta d-oeste', case=False)

# %%
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace('barra de  santo antonio', 'barra de santo antonio', case=False)
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].str.replace(r'\s\s+', ' ', regex=True)

# %%
geolocation_df = geolocation_df.sort_values(by='geolocation_city')

# %%
unique_cities2=geolocation_df['geolocation_city'].unique()
chunk_size=300
for i in range(0,len(unique_cities2),chunk_size):
     print(unique_cities2 [i:i+ chunk_size])
# Out:
# ['sao paulo' 'sao bernardo do campo' 'jundiai' 'taboao da serra'
#  'sao jose dos campos' 'osasco' 'carapicuiba' 'barueri'
#  'santana de parnaiba' 'pirapora do bom jesus' 'jandira' 'itapevi' 'cotia'
#  'vargem grande paulista' 'embu das artes' 'itapecerica da serra' 'embu'
#  'sao lourenco da serra' 'embu guacu' 'juquitiba' 'guarulhos' 'adamantina'
#  'guarulhos sao paulo' 'aruja' 'santa isabel' 'mairipora' 'cajamar'
#  'caieiras' 'jordanesia' 'polvilho' 'maua' 'franco da rocha'
#  'francisco morato' 'poa' 'itaquaquecetuba' 'ferraz de vasconcelos'
#  'suzano' 'mogi das cruzes' 'mogidascruzes' 'salesopolis' 'biritiba mirim'
#  'guararema' 'santo andre' 'ribeirao pires' 'rio grande da serra'
#  'sao caetano do sul' 'sbcampo' 'diadema' 'santos' 'bertioga' 'caruara'
#  'sao vicente' 'guaruja' 'cubatao' 'sao sebastiao' 'ubatuba' 'ilhabela'
#  'caraguatatuba' 'maresias' 'sao francisco da praia' 'mongagua'
#  'praia grande' 'itanhaem' 'peruibe' 'itariri' 'pedro de toledo'
#  'ana dias' 'miracatu' 'juquia' 'pariquera acu' 'cajati' 'registro'
#  'jacupiranga' 'ilha comprida' 'barra do turvo' 'eldorado' 'iguape'
#  'cananeia' 'sete barras' 'taubate' 'natividade da serra' 'tremembe'
#  'lagoinha' 'redencao da serra' 'catucaba' 'sao luiz do paraitinga'
#  'sao luis do paraitinga' 'cacapava' 'paraibuna' 'jambeiro'
#  'monteiro lobato' 'sao francisco xavier' 'jacarei' 'santa branca'
#  'igarata' 'pindamonhangaba' 'sao bento do sapucai' 'campos do jordao'
#  'santo antonio do pinhal' 'guaratingueta' 'potim' 'aparecida' 'cunha'
#  'roseira' 'campos de cunha' 'lorena' 'cachoeira paulista' 'piquete'
#  'silveiras' 'canas' 'cruzeiro' 'lavrinhas' 'arapei' 'queluz' 'bananal'
#  'sao jose do barreiro' 'areias' 'atibaia' 'braganca paulista'
#  'bom jesus dos perdoes' 'piracaia' 'bom jesus dos perdões' 'pedra bela'
#  'joanopolis' 'vargem' 'nazare paulista' 'pinhalzinho' 'tuiuti' 'campinas'
#  'artur nogueira' 'hortolandia' 'paulinia' 'sumare' 'cosmopolis'
#  'monte mor' 'engenheiro coelho' 'itatiba' 'vinhedo' 'valinhos'
#  'varzea paulista' 'louveira' 'jarinu' 'campo limpo paulista' 'morungaba'
#  'itupeva' 'indaiatuba' 'capivari' 'salto' 'itu' 'nova odessa' 'cabreuva'
#  'elias fausto' 'rafard' 'rio das pedras' 'jacare' 'mombuca'
#  'jacare (cabreuva)' 'cardeal' 'bom fim do bom jesus' 'americana'
#  'limeira' 'piracicaba' "santa barbara d'oeste" 'saltinho' 'cordeiropolis'
#  'iracemapolis' 'santa barbara d oeste' 'santa barbara doeste'
#  'santa barbara d`oeste' 'rio claro' 'sao carlos' 'ipeuna'
#  'santa gertrudes' 'itirapina' 'charqueada' 'ribeirao bonito' 'sao pedro'
#  'dourado' 'corumbatai' 'analandia' 'aguas de sao pedro' 'santa eudoxia'
#  'agua vermelha' 'araras' 'pirassununga' 'porto ferreira'
#  'santa cruz das palmeiras' 'santa rita do passa quatro' 'leme'
#  'descalvado' 'santa cruz da conceicao' 'mococa' 'sao jose do rio pardo'
#  'casa branca' 'caconde' 'tambau' 'tapiratiba' 'divinolandia'
#  'sao benedito das areias' 'itobi' 'sao sebastiao da grama' 'igarai'
#  'lagoa branca' 'venda branca' 'jaguariuna' 'vargem grande do sul'
#  'mogi guacu' 'santo antonio de posse' 'sao joao da boa vista'
#  'mogi mirim' 'holambra' 'aguai' 'conchal' 'estiva gerbi' 'aguas da prata'
#  'monte alegre do sul' 'martinho prado junior' 'sao roque da fartura'
#  'amparo' 'itapira' 'socorro' 'lindoia' 'aguas de lindoia' 'pedreira'
#  'serra negra' 'esao pauloirito santo do pinhal' 'barao ataliba nogueira'
#  'santo antonio do jardim' 'eleuterio' 'ribeirao preto' 'sertaozinho'
#  'serrana' 'pontal' 'cravinhos' 'bonfim paulista' 'guatapara' 'dumont'
#  'candia' 'cajuru' 'luis antonio' 'sao simao' 'santa rosa de viterbo'
#  'serra azul' 'cassia dos coqueiros' 'santa cruz da esao pauloeranca'
#  'santo antonio da alegria' 'brodowski' 'batatais' 'altinopolis' 'franca'
#  'jeriquara' 'rifaina' 'sao jose da bela vista' 'cristais paulista'
#  'patrocinio paulista' 'pedregulho' 'itirapua' 'ribeirao corrente'
#  'restinga' 'franca sao paulo' 'igarapava' 'ituverava' 'miguelopolis'
#  'aramina' 'buritizal' 'guara' 'sao benedito da cachoeirinha' 'pioneiros'
#  'ipua' 'sao joaquim da barra' 'morro agudo' 'orlandia' 'jardinopolis'
#  'sales oliveira' 'nuporanga' 'juruce' 'barretos' 'bebedouro' 'viradouro'
#  'guaira' 'colombia' 'taiuva' 'pitangueiras' 'monte azul paulista'
#  'colina' 'severinia' 'taiacu' 'terra roxa' 'ibitiuva' 'jaborandi'
#  'taquaral' 'araraquara' 'gaviao peixoto' 'jaboticabal' 'santa lucia'
#  'barrinha' 'ibate' 'americo brasiliense' 'rincao' 'guariba']
# ['pradopolis' 'motuca' 'ibitinga' 'itapolis' 'novo horizonte' 'tabatinga'
#  'nova europa' 'irapua' 'nova america' 'borborema'
#  'boa esao pauloeranca do sul' 'sales' 'trabiju' 'tapinas' 'curupa'
#  'sao jose do rio preto' 'mirassol' 'monte aprazivel' 'tanabi'
#  'neves paulista' 'jaci' 'bady bassitt' 'sebastianopolis do sul'
#  'guapiacu' 'nhandeara' 'balsamo' 'potirendaba' 'poloni' 'mirassolandia'
#  'ipigua' 'engenheiro balduino' 'uniao paulista' 'jose bonifacio'
#  'buritama' 'turiuba' 'macaubal' 'mendonca' 'nipoa' 'adolfo' 'moncoes'
#  'planalto' 'zacarias' 'ubarana' 'moncões' 'nova alianca' 'nova itapirema'
#  'lourdes' 'pereira barreto' 'ilha solteira' 'itapura' 'general salgado'
#  'auriflama' 'magda' 'floreal' 'gastao vidigal' 'nova luzitania'
#  'sao joao de iracema' 'suzanapolis' 'sud mennucci' 'guzolandia'
#  'nova castilho' "bandeirantes d'oeste" 'paulo de faria' 'olimpia'
#  'riolandia' 'icem' 'nova granada' 'palestina' 'onda verde' 'guaraci'
#  'orindiuva' 'altair' 'cajobi' 'embauba' 'monte verde paulista' 'baguacu'
#  'valentim gentil' 'cardoso' 'votuporanga' 'cosmorama' 'pontes gestal'
#  'americo de campos' 'boa vista dos andradas' 'mira estrela' 'parisi'
#  'alvares florence' 'fernandopolis' 'ouroeste' 'meridiano' 'indiapora'
#  "estrela d'oeste" 'estrela d oeste' "guarani d'oeste" 'estrela doeste'
#  'pedranopolis' 'macedonia' 'sao joao das duas pontes' 'populina'
#  'brasitania' 'tres fronteiras' 'urania' 'jales' 'santa fe do sul'
#  "palmeira d'oeste" 'vitoria brasil' 'santa albertina' 'turmalina'
#  'santana da ponte pensa' 'santa salete' 'aparecida d oeste'
#  "santa clara d'oeste" 'rubineia' 'dirce reis' 'sao francisco'
#  "santa rita d'oeste" 'dolcinopolis' 'marinopolis' "aparecida d'oeste"
#  'paranapua' 'mesopolis' 'palmeira doeste' 'asao pauloasia' 'pontalinda'
#  'palmeira d oeste' 'santa clara d oeste' 'nova canaa paulista'
#  'santa rita d oeste' 'aparecida doeste' 'santa rita doeste' 'pindorama'
#  'urupes' 'itajobi' 'catanduva' 'paraiso' 'tabapua' 'catigua'
#  'palmares paulista' 'cedral' 'novais' 'pirangi' 'uchoa' 'ibira'
#  'elisiario' 'marapoama' 'sao joao de itaguacu' 'roberto'
#  'termas de ibira' 'ariranha' 'matao' 'taquaritinga' 'santa ernestina'
#  'monte alto' 'santa adelia' 'vista alegre do alto' 'botelho'
#  'fernando prestes' 'aparecida de monte alto' 'dobrada'
#  'candido rodrigues' 'agulha' 'jurupema' 'aracatuba'
#  'santo antonio do aracangua' 'birigüi' 'piacatu' 'birigui' 'bilac'
#  'clementina' 'gabriel monteiro' 'glicerio' 'brauna' 'coroados'
#  'santopolis do aguapei' 'brejo alegre' 'juritis' 'penapolis' 'promissao'
#  'luiziania' 'avanhandava' 'alto alegre' 'barbosa' 'lins' 'guaicara'
#  'sabino' 'getulina' 'guaimbe' 'cafelandia' 'guaranta' 'simoes'
#  'presidente alves' 'pongai' 'avai' 'pirajui' 'uru' 'balbinos'
#  'guararapes' 'rubiacea' 'bento de abreu' 'mirandopolis' 'valparaiso'
#  'lavinia' 'tres aliancas' 'andradina' 'castilho' 'guaracai'
#  'murutinga do sul' 'nova independencia' 'bauru' 'arealva' 'agudo'
#  'iacanga' 'reginopolis' 'paulistania' 'domelia' 'jacuba' 'jau'
#  'pederneiras' 'itapui' 'bariri' 'itaju' 'boraceia' 'macatuba' 'bocaina'
#  'santelmo' 'potunduva' 'guaianas' 'barra bonita' 'brotas'
#  'igaracu do tiete' 'dois corregos' 'mineiros do tiete' 'torrinha'
#  'santa maria da serra' 'guarapua' 'lupercio' 'garca' 'duartina' 'galia'
#  'alvaro de carvalho' 'piratininga' 'cabralia paulista' 'ubirajara'
#  'alvinlandia' 'lucianopolis' 'fernao' 'jafa' 'marilia' 'julio mesquita'
#  'queiroz' 'pompeia' 'vera cruz' 'oriente' 'ocaucu' 'tupa' 'bastos'
#  'herculandia' 'iacri' 'quintana' 'arco iris' 'osvaldo cruz' 'lucelia'
#  'rinopolis' 'parapua' 'sagres' 'inubia paulista' 'pracinha' 'salmourao'
#  'junqueiropolis' 'pacaembu' 'flora rica' 'florida paulista' 'irapuru'
#  'mariapolis' 'dracena' 'ouro verde' "sao joao do pau d'alho" 'panorama'
#  'tupi paulista' 'monte castelo' 'pauliceia' 'santa mercedes'
#  'nova guataporanga' 'sao joao do pau d alho' 'jamaica'
#  'sao joao do pau dalho' 'sao joao do pau d%26apos%3balho' 'sorocaba'
#  'mairinque' 'capela do alto' 'sao roque' 'votorantim' 'pilar do sul'
#  'aluminio' 'aracariguama' 'salto de pirapora' 'aracoiaba da serra'
#  'piedade' 'ibiuna' 'tapirai' 'paruru']
# ['angatuba' 'sao miguel arcanjo' 'alambari' 'tatui' 'itapetininga'
#  'sarapui' 'cesario lange' 'buri' 'porangaba' 'guarei' 'torre de pedra'
#  'campina do monte alegre' 'conceicao' 'rechan' 'gramadinho' 'quadra'
#  'apiai' 'capao bonito' 'guapiara' 'itaoca' 'ribeira' 'iporanga'
#  'ribeirao grande' 'barra do chapeu' 'itapirapua paulista' 'itapeva'
#  'itarare' 'nova campina' 'itabera' 'itaporanga' 'taquarivai' 'riversul'
#  'guarizinho' 'ribeirao branco' 'barao de antonina'
#  'bom sucesso de itarare' 'boituva' 'cerquilho' 'porto feliz' 'pereiras'
#  'ipero' 'conchas' 'laranjal paulista' 'tiete' 'jumirim' 'bofete'
#  'maristela' 'areiopolis' 'lencois paulista' 'sao manuel' 'botucatu'
#  'aparecida de sao manuel' 'borebi' 'anhembi' 'pardinho' 'itatinga'
#  'alfredo guedes' 'pratania' 'rubiao junior' 'piramboia' 'avare'
#  'cerqueira cesar' 'taquarituba' 'paranapanema' 'holambra ii'
#  'coronel macedo' 'itai' 'oleo' 'manduri' 'iaras' 'aguas de santa barbara'
#  'arandu' 'piraju' 'fartura' 'taguai' 'sarutaia' 'timburi' 'tejupa'
#  'santa cruz do rio pardo' 'ipaussu' 'chavantes' 'sao pedro do turvo'
#  'bernardino de campos' 'esao pauloirito santo do turvo' 'canitar' 'irape'
#  'sodrelia' 'caporanga' 'presidente prudente' 'alvares machado'
#  'santo expedito' 'floresta do sul' 'alfredo marcondes' 'eneida'
#  'pirapozinho' 'teodoro sampaio' 'narandiba' 'euclides da cunha paulista'
#  'tarabai' 'rosana' 'sandovalina' 'mirante do paranapanema'
#  'estrela do norte' 'primavera' 'cuiaba paulista' 'costa machado'
#  'santo anastacio' 'presidente bernardes' 'emilianopolis'
#  'ribeirao dos indios' 'nova patria' 'presidente venceslau'
#  'presidente epitacio' 'maraba paulista' 'caiua' 'piquerobi' 'campinal'
#  'regente feijo' 'taciba' 'martinopolis' 'indiana' 'esao pauloigao'
#  'anhumas' 'caiabu' 'iubatinga' 'tecainda' 'rancharia' 'joao ramalho'
#  'nantes' 'iepe' 'agisse' 'gardenia' 'paraguacu paulista' 'quata'
#  'oscar bressane' 'lutecia' 'assis' 'candido mota' 'maracai' 'taruma'
#  'cruzalia' 'echapora' 'pedrinhas paulista' 'florinia' 'florinea'
#  'frutal do campo' 'nova alexandria' 'sao jose das laranjeiras' 'ourinhos'
#  'palmital' 'ibirarema' 'platina' 'salto grande' 'campos novos paulista'
#  'ribeirao do sul' 'rio de janeiro'
#  'rio de janeiro, rio de janeiro, brasil' 'rj' 'rio janeiro'
#  'campo grande' 'seropedica' 'itaguai' 'mangaratiba' 'itacurussa'
#  'vila muriqui' 'conceicao de jacarei' 'parati' 'paraty' 'angra dos reis'
#  'ilha grande' 'parati mirim' 'niteroi' 'sao goncalo' 'itaborai' 'tangua'
#  'marica' 'inoa' 'duque de caxias' 'sao joao de meriti' 'petropolis'
#  'sao jose do vale do rio preto' 'paraiba do sul' 'tres rios'
#  'comendador levy gasao pauloarian' 'werneck' 'areal' 'sapucaia'
#  'jamapara' 'nossa senhora da aparecida' 'anta' 'piao' 'afonso arinos'
#  'guapimirim' 'teresopolis' 'mage' 'guia de pacobaiba' 'piabeta'
#  'inhomirim' 'santo aleixo' 'nova iguacu' 'belford roxo' 'queimados'
#  'japeri' 'mesquita' 'nilopolis' 'paracambi' 'engenheiro paulo de frontin'
#  'sacra familia do tingua' 'mendes' 'miguel pereira' 'paty do alferes'
#  'governador portela' 'avelar' 'conrado' 'pirai' 'barra do pirai'
#  'pinheiral' 'sao jose do turvo' 'california da barra' 'arrozal' 'ipiabas'
#  'vargem alegre' 'dorandia' 'santanesia'
#  'california da barra (barra do pirai)' 'volta redonda' 'barra mansa'
#  'quatis' 'lidice' 'getulandia' 'passa tres' 'resende' 'porto real'
#  'itatiaia' 'visconde de maua' 'penedo' 'penedo (itatiaia)'
#  'engenheiro passos' 'valenca' 'taboas' 'rio das flores'
#  'barao de juparana' 'conservatoria' 'santa isabel do rio preto'
#  'manuel duarte' 'parapeuna' 'vassouras' 'andrade pinto' 'macae'
#  'carapebus' 'sana' 'frade' 'campos dos goytacazes' 'campos dos goytacaze'
#  'goitacazes' 'cardoso moreira' 'santo amaro de campos'
#  'vila nova de campos' 'sao sebastiao de campos' 'travessao' 'tocos'
#  'morro do coco' 'santa maria' 'italva' 'sao joao da barra' 'barcelos'
#  'sao francisco de itabapoana' 'bom jesus do itabapoana' 'natividade'
#  'itaperuna' 'varre sai' 'porciuncula' 'retiro do muriae' 'laje do muriae'
#  'comendador venancio' 'raposo' 'purilandia' 'boa ventura' 'santa clara'
#  'calheiros' 'carabucu' 'sao fidelis' 'santo antonio de padua' 'miracema'
#  'aperibe' 'cambuci' 'sao joao do paraiso' 'colonia' 'sao jose de uba'
#  'pureza' 'monte alegre' 'tres irmaos' 'cambiasca' 'ipuca'
#  'paraiso do tobias' 'macuco' 'cordeiro' 'portela' 'cantagalo'
#  'sao sebastiao do alto']
# ['itaocara' 'laranjais' 'ipituna' 'boa sorte' 'santa rita da floresta'
#  'valao do barro' 'nova friburgo' 'japuiba' 'carmo' 'cachoeiras de macacu'
#  'bom jardim' 'duas barras' 'papucaia' 'sumidouro' 'banquete'
#  'porto velho do cunha' 'sao jose do ribeirao' 'trajano de moraes'
#  'conceicao de macabu' 'quissama' 'santa maria madalena'
#  'trajano de morais' 'visconde de imbe' 'rio das ostras' 'rio bonito'
#  'casimiro de abreu' 'silva jardim' 'barra de sao joao'
#  'boa esao pauloeranca' 'cabo frio' 'arraial do cabo' 'araruama'
#  'armacao dos buzios' 'sao pedro da aldeia' 'saquarema' 'iguaba grande'
#  'armacao de buzios' 'sao vicente de paula' 'buzios' 'bacaxa'
#  'tamoios (cabo frio)' 'bacaxa (saquarema) distrito' 'sampaio correia'
#  'vitoria' 'vila velha' 'serra' 'cariacica' 'aracruz' 'viana' 'fundao'
#  'coqueiral' 'praia grande (fundao) distrito' 'anchieta' 'rio novo do sul'
#  'guarapari' 'iconha' 'marechal floriano' 'domingos martins'
#  'alfredo chaves' 'piuma' 'vargem alta' 'araguaia' 'isabel' 'paraju'
#  'jacigua' 'arace' 'cachoeiro de itapemirim' 'castelo' 'ibatiba'
#  'presidente kennedy' 'venda nova do imigrante' 'itapemirim' 'irupi'
#  'marataizes' 'conceicao do castelo' 'iuna' 'itaipava' 'conduru'
#  'muniz freire' 'vargem grande do soturno' 'corrego dos monos'
#  'sao joao de vicosa' 'pacotuba' 'burarama' 'venda nova do imigrante es'
#  'sao jose do calcado' 'mimoso do sul' 'muqui' 'atilio vivacqua' 'apiaca'
#  'bom jesus do norte' 'sao jose das torres' 'alto calcado' 'cafe' 'alegre'
#  'jeronimo monteiro' 'divino de sao lourenco' 'dores do rio preto'
#  'guacui' 'ibitirama' 'celina' 'rive' 'sao pedro de rates'
#  'afonso claudio' 'santa maria de jetiba' 'santa teresa'
#  'sao roque do canaa' 'laranja da terra' 'itarana' 'santa leopoldina'
#  'sao roque do cannaa' 'joao neiva' 'ibiracu' 'itaguacu' 'brejetuba'
#  'itaimbe' 'santo antonio do canaa' 'sao joao de petropolis' 'acioli'
#  'colatina' 'sao gabriel da palha' 'baixo guandu' 'pancas' 'vila valerio'
#  'mantenopolis' 'marilandia' 'vila verde' 'alto rio novo'
#  'governador lindenberg' 'sao domingos do norte' 'aguia branca' 'lajinha'
#  'novo brasil' 'quilometro 14 do mutum' 'santa luzia de mantenopolis'
#  'alto mutum preto' 'ecoporanga' 'nova venecia' 'montanha' 'mucurici'
#  'vila pavao' 'agua doce do norte' 'barra de sao francisco' 'vila nelita'
#  'itabaiana' 'paulista' 'ponto belo' 'santo agostinho'
#  'governador lacerda de aguiar' 'monte sinai' 'vinhatico'
#  'conceicao da barra' 'linhares' 'sao mateus' 'sooretama' 'jaguare'
#  'pinheiros' 'pedro canario' 'rio bananal' 'sao joao do sobrado'
#  'braco do rio' 'cristal do norte' 'sao jorge do tiradentes' 'itaunas'
#  'linharesl' 'belo horizonte' 'belo horizonta' 'bh' 'contagem' 'sarzedo'
#  'mario campos' 'ibirite' 'betim' 'igarape' 'sao joaquim de bicas'
#  'santa luzia' 'vesao pauloasiano' 'sao jose da lapa' 'lagoa santa'
#  'confins' 'pedro leopoldo' 'vera cruz de minas' 'ribeirao das neves'
#  'taquaracu de minas' 'nova lima' 'rio acima' 'raposos' 'sabara' 'ravena'
#  'caete' 'rocas novas' 'nova uniao' 'morro vermelho'
#  'governador valadares' 'timoteo' 'coronel fabriciano' 'ipatinga'
#  'itanhomi' 'pescador' 'nova modica' 'frei inocencio' 'alpercata'
#  'tarumirim' 'ipaba' 'engenheiro caldas' 'santana do paraiso' 'marlieria'
#  'iapu' 'dom cavati' 'antonio dias' 'marilac' 'acucena' 'capitao andrade'
#  'mathias lobato' 'naque' 'periquito' 'tumiritinga' 'braunas'
#  'belo oriente' 'sao joao do oriente' 'sobralia' 'perpetuo socorro'
#  'sao jose do acacio' 'bugre' 'fernandes tourinho' 'naque nanuque'
#  'jaguaracu' 'sao sebastiao de braunas' 'goiabal' 'joanesia' 'baguari'
#  'chonim' 'sao sebastiao da barra' 'sao vicente do rio doce' 'mantena'
#  'itueta' 'aimores' 'conselheiro pena' 'mendes pimentel'
#  'resao paulolendor' 'itabirinha' 'sao joao do manteninha' 'goiabeira'
#  'divino das laranjeiras' 'floresta' 'santa rita do itueto'
#  'sao sebastiao da vala' 'central de minas' 'itabirinha de mantena'
#  'cuparaque' 'sao geraldo do baixio' 'galileia' 'alvarenga'
#  'central de santa helena' 'quatituba' 'limeira de mantena'
#  'sapucaia do norte' 'conceicao do capim' 'sao felix de minas'
#  'boa uniao de itabirinha' 'ferruginha' 'sao jose do itueto'
#  'campo alegre de minas' 'nova belem' 'barra do cuiete' 'calixto'
#  'penha do capim' 'barra do ariranha' 'independencia' 'aldeia'
#  'abre campo' 'ubaporanga' 'matipo' 'caratinga' 'inhapim' 'urucania'
#  'sao pedro dos ferros' 'santa rita de minas' 'raul soares' 'rio casca'
#  'piedade de caratinga' 'imbe de minas' 'sericita'
#  'sao domingos das dores' 'entre folhas' 'bom jesus do galho'
#  'pedra bonita' 'jequeri' 'aguas ferreas' 'padre fialho' 'corrego novo'
#  'santa barbara do leste' 'sao sebastiao do anta' 'piedade de ponte nova'
#  'santo antonio do grama' 'sao vicente do grama' 'vermelho novo'
#  "pingo d'agua" 'santa cruz do escalvado' 'bicuiba']
# ['pingo d agua' 'santa efigenia' 'sao joao do jacutinga' 'vermelho velho'
#  'santa luzia de caratinga' 'granada' 'santana do tabuleiro'
#  'sao vicente da estrela' 'santo antonio do manhuacu' 'grota' 'moeda'
#  'ponte nova' 'mariana' 'itabirito' 'ouro preto' 'brumadinho'
#  'entre rios de minas' 'piedade dos gerais' 'amarantina' 'antonio pereira'
#  'cachoeira do campo' 'desterro de entre rios' 'itaguara' 'barra longa'
#  'oratorios' 'rio doce' 'cachoeira do brumado' 'sao bras do suacui'
#  'amparo da serra' 'acaiaca' 'dom silverio' 'bonfim' 'belo vale'
#  'crucilandia' 'sem peixe' 'guaraciaba' 'santa rita durao' 'lavras novas'
#  'jeceaba' 'santo antonio do leite' 'passagem de mariana'
#  'monsenhor horta' 'claudio manuel' 'vau acu' 'bandeirantes'
#  'diogo de vasconcelos' 'rio manso' 'santa rita de ouro preto' 'furquim'
#  'sao bartolomeu' 'rodrigo silva' 'santana do paraopeba'
#  'piedade do paraopeba' 'rosario do pontal' 'oliveira' 'divinopolis'
#  'formiga' 'santo antonio do monte' 'luz' 'carmopolis de minas'
#  'nova serrana' 'arcos' 'lagoa da prata' 'lamounier'
#  'santo antonio dos campos' 'perdigao' 'pimenta' 'sao goncalo do para'
#  'pains' 'monsenhor joao alexandre' 'itapecerica' 'morro do ferro'
#  'carmo da mata' 'carmo do cajuru' 'camacho' 'piracema'
#  'sao francisco de paula' 'claudio' 'sao sebastiao do oeste' 'esteios'
#  'neolandia' 'pedra do indaia' 'passa tempo' 'corrego fundo' 'japaraiba'
#  'sao jose dos salgados' 'boa vista de minas' 'martins guimaraes'
#  'para de minas' 'itauna' 'pequi' 'juatuba' 'abaete' 'maravilhas'
#  'bom desao pauloacho' 'martinho campos' 'papagaios'
#  'morada nova de minas' 'moema' 'estrela do indaia' 'mateus leme'
#  'pitangui' 'araujos' 'pompeu' 'conceicao do para' 'florestal' 'ibitira'
#  'itatiaiucu' 'azurita' 'quartel geral' 'igaratinga' 'paineiras'
#  'dores do indaia' 'onca de pitangui' 'sao jose da varginha'
#  'leandro ferreira' 'biquinhas' 'engenho do ribeiro' 'cedro do abaete'
#  'serra da saudade' 'alberto isaacson' 'santa terezinha de minas'
#  'pocoes de paineiras' 'antunes' 'antunes (igaratinga)' 'torneiros'
#  'sete lagoas' 'paraopeba' 'matozinhos' 'curvelo' 'capim branco'
#  'prudente de morais' 'esmeraldas' 'baldim' 'santana de pirapama'
#  'funilandia' 'caetanopolis' 'felixlandia' 'inhauma' 'fortuna de minas'
#  'melo viana' 'jequitiba' 'cachoeira da prata' 'cordisburgo' 'mocambeiro'
#  'aracai' 'santa rita do cedro' 'morro da garca' 'anguereta' 'inimutaba'
#  'conceicao do mato dentro' 'carmesia' 'congonhas do norte'
#  'sao sebastiao do rio preto' 'ferros' 'esmeraldas de ferros'
#  'dom joaquim' 'santana do riacho' 'santo antonio do norte'
#  'jaboticatubas' 'itambe do mato dentro' 'santo antonio do rio abaixo'
#  'dores de guanhaes' 'morro do pilar' 'passabem' 'gororos'
#  'joao monlevade' 'nova era' 'barao de cocais' 'santa barbara'
#  'santa maria de itabira' 'itabira' 'bela vista de minas'
#  'sao goncalo do rio abaixo' 'rio piracicaba' 'alvinopolis' 'catas altas'
#  'sao domingos do prata' 'dionisio' 'cocais' 'sao jose do goiabal'
#  'bom jesus do amparo' 'ipoema' 'fonseca' 'senhora do carmo' 'barra feliz'
#  'juiz de fora' 'lima duarte' 'ewbank da camara'
#  'santa barbara do monte verde' 'matias barbosa' 'santa rita de jacutinga'
#  'guarani' 'belmiro braga' 'goiana' 'rio pomba' 'pirauba' 'chacara'
#  'paiva' 'rio preto' 'merces' 'tabuleiro' 'rio novo' 'coronel pacheco'
#  'simao pereira' 'conceicao da ibitipoca' 'silveirania' 'piau'
#  'santana do garambeu' 'sarandira' 'olaria' 'rosario de minas'
#  'pedro teixeira' 'barbacena' 'aracitaba' 'dores de campos'
#  'santos dumont' 'carandai' 'mantiqueira do palmital' 'cipotanea'
#  'barroso' 'alto rio doce' 'senhora dos remedios' 'correia de almeida'
#  'capela nova' 'santa rita do ibitipoca' 'santa barbara do tugurio'
#  'antonio carlos' 'senhora das dores' 'alfredo vasconcelos'
#  'piedade do rio grande' 'desterro do melo' 'bias fortes' 'ressaquinha'
#  'ibertioga' 'sao joao da serra' 'pinheiro grosso' 'costas da mantiqueira'
#  'abreus' 'oliveira fortes' 'vitorinos' 'dores do paraibuna'
#  'vitorinos alto rio doce' 'sao sebastiao dos torres' 'sao joao del rei'
#  'lagoa dourada' 'tiradentes' 'resende costa' 'sao tiago'
#  'conceicao da barra de minas' 'coronel xavier chaves'
#  'santa cruz de minas' 'itutinga' 'nazareno' 'sao sebastiao da vitoria'
#  'prados' 'ritapolis' 'merces de agua limpa' 'rio das mortes'
#  'conselheiro lafaiete' 'ouro branco' 'congonhas' 'casa grande' 'lamim'
#  'piranga' 'senhora de oliveira' 'rio esao pauloera' 'cristiano otoni'
#  'santana dos montes' 'queluzito' 'itaverava' 'caranaiba' 'alto maranhao'
#  'catas altas da noruega' 'pinheiros altos' 'santo antonio do pirapetinga'
#  'rio melo' 'vicosa' 'visconde do rio branco' 'cajuri' 'uba' 'ervalia'
#  'coimbra' 'sao geraldo' 'sao miguel do anta' 'porto firme' 'tocantins'
#  'guidoval' 'divinesia' 'teixeiras' 'senador firmino' 'rodeiro'
#  'guiricema' 'dores do turvo' 'araponga' 'paula candido' 'bras pires'
#  'cachoeira de santa cruz' 'canaa' 'pedra do anta']
# ['descoberto' 'alem paraiba' 'sao domingos' 'sao joao nepomuceno' 'bicas'
#  'guarara' 'mar de esao pauloanha' 'pequeri' 'angustura'
#  'santo antonio do aventureiro' 'rochedo de minas' 'maripa de minas'
#  'senador cortes' 'santana do deserto' 'chiador' 'leopoldina' 'mirai'
#  'cataguases' 'pirapetinga' 'sao sebastiao da vargem alegre' 'recreio'
#  'santana de cataguases' 'cataguarino' 'astolfo dutra' 'palma'
#  'volta grande' 'estrela dalva' 'itamarati de minas' 'laranjal' 'argirita'
#  'itapirucu' 'dona euzebia' 'vista alegre' 'piacatuba' 'sereno'
#  'ribeiro junqueira' 'cisneiros' 'sao manoel do guaiacu' 'tebas'
#  'eugenopolis' 'carangola' 'muriae' 'divino' 'rosario da limeira'
#  'fervedouro' 'vieiras' 'orizania' 'esao pauloera feliz' 'tombos'
#  'faria lemos' 'miradouro' 'caparao' 'sao francisco do gloria' 'caiana'
#  'silveira carvalho' 'barao de monte alto' 'vermelho'
#  'patrocinio do muriae' 'antonio prado de minas' 'pedra dourada'
#  'cachoeira alegre' 'alvorada' 'catune' 'ponte alta de minas' 'manhuacu'
#  'santa margarida' 'manhumirim' 'taparuba' 'simonesia' 'ipanema'
#  'martins soares' 'sao joao do manhuacu' 'alto jequitiba' 'caputira'
#  'mutum' 'alto caparao' 'santana do manhuacu' 'sao jose do mantimento'
#  'sao pedro do avai' 'realeza' 'pocrane' 'durande' 'luisburgo' 'alegria'
#  'ribeirao de sao domingos' 'chale' 'reduto' 'sao sebastiao do sacramento'
#  'conceicao de ipanema' 'realeza (manhuacu)' 'roseiral' 'varginha'
#  'tres pontas' 'alfenas' 'carmo do rio claro' 'campos gerais' 'areado'
#  'paraguacu' 'serrania' 'conceicao da aparecida' 'eloi mendes'
#  'campo do meio' 'divino esao pauloirito santo' 'monte belo' 'fama'
#  'santana da vargem' 'alterosa' 'guape' 'divisa nova' 'ilicinea'
#  'corrego do ouro' 'lavras' 'campo belo' 'perdoes' 'carmo da cachoeira'
#  'ingai' 'santo antonio do amparo' 'bom sucesso' 'itumirim' 'nepomuceno'
#  'candeias' 'perdões' 'carrancas' 'cristais' 'santana do jacare'
#  'macuco de minas' 'aguanil' 'ribeirao vermelho' 'cana verde' 'luminarias'
#  'ijaci' 'lavras mg' 'ibituruna' 'bom jardim de minas' 'liberdade'
#  'sao vicente de minas' 'andrelandia' 'passa vinte'
#  'madre de deus de minas' 'arantina' 'bocaina de minas' 'tabuao'
#  'sao lourenco' 'lambari' 'santana do capivari' 'itanhandu' 'heliodora'
#  'sao goncalo do sapucai' 'caxambu' 'tres coracoes' 'cambuquira'
#  'passa quatro' 'baependi' 'campanha' 'alagoa' 'jesuania' 'cruzilia'
#  'dom vicoso' 'conceicao do rio verde' 'tres coracões'
#  'sao thome das letras' 'pouso alto' 'cristina' 'minduri'
#  'monsenhor paulo' 'virginia' 'carmo de minas' 'serranos' 'itamonte'
#  'soledade de minas' 'cordislandia' 'olimpio noronha' 'aiuruoca'
#  'sao bento abade' 'carvalhos' 'turvolandia' 'sao sebastiao do rio verde'
#  'seritinga' 'pouso alegre' 'maria da fe' 'itajuba' 'bueno brandao'
#  'brasopolis' 'conceicao dos ouros' 'cachoeira de minas' 'monte siao'
#  'santa rita do sapucai' 'brazopolis' 'ipuiuna'
#  'sao sebastiao da bela vista' 'ouro fino' 'pedralva' 'borda da mata'
#  'inconfidentes' 'jacutinga' 'careacu' 'natercia' 'sao jose do alegre'
#  'tocos do moji' 'estiva' 'luminosa' 'piranguinho' 'senador jose bento'
#  'delfim moreira' 'esao pauloirito santo do dourado'
#  'conceicao das pedras' 'silvianopolis' 'congonhal' 'wenceslau braz'
#  'pirangucu' 'marmelopolis' 'albertina' 'sao joao da mata' 'crisolia'
#  'itaim' 'cambui' 'monte verde' 'sapucai mirim' 'extrema' 'camanducaia'
#  'senador amaral' 'paraisopolis' 'munhoz' 'goncalves' 'bom repouso'
#  'toledo' 'consolacao' 'corrego do bom jesus' 'sao mateus de minas'
#  'pocos de caldas' 'campestre' 'carvalhopolis' 'machado' 'andradas'
#  'botelhos' 'caldas' 'poco fundo' 'palmeiral' 'ibitiura de minas'
#  'bandeira do sul' 'santa rita de caldas' 'sao goncalo de botelhos'
#  'santana de caldas' 'guaxupe' 'muzambinho' 'cabo verde'
#  'sao pedro da uniao' 'arceburgo' 'guaranesia' 'juruaia' 'nova resende'
#  'santa cruz do prata' 'petunia' 'ibiraci' 'monte santo de minas'
#  'itau de minas' 'cassia' 'capetinga' 'sao sebastiao do paraiso' 'passos'
#  'bom jesus da penha' 'piumhii' 'capitolio' 'sao tomas de aquino'
#  'alpinopolis' 'sao joao batista do gloria' 'piumhi' 'pratapolis'
#  'fortaleza de minas' 'sao roque de minas' 'doresopolis' 'delfinopolis'
#  'itamogi' 'vargem bonita' 'jacui' 'sao jose da barra' 'claraval'
#  'guardinha' 'uberaba' 'araxa' 'sacramento' 'perdizes' 'prata'
#  'conceicao das alagoas' 'santa juliana' 'conquista' 'delta' 'tapira'
#  'verissimo' 'campo florido' 'agua comprida' 'pedrinopolis' 'nova ponte'
#  'ponte alta' 'guaxima' 'campina verde' 'iturama' 'frutal' 'planura'
#  'fronteira']
# ['limeira do oeste' 'sao sebastiao do pontal' 'sao francisco de sales'
#  'itapagipe' 'uniao de minas' 'carneirinho' 'pirajuba' 'alexandrita'
#  'comendador gomes' 'aparecida de minas' 'honoropolis'
#  'limeira do oeste mg' 'limeira d oeste' 'estrela da barra'
#  'santa vitoria' 'ituiutaba' 'capinopolis' 'ipiacu' 'canapolis'
#  'cachoeira dourada' 'centralina' 'gurinhata' 'chaveslandia' 'perdilandia'
#  'uberlandia' 'araguari' 'arapora' 'monte alegre de minas' 'tupaciguara'
#  'indianopolis' 'cascalho rico' 'amanhece' 'grupiara' 'tapuirama'
#  'martinesia' 'monte carmelo' 'abadia dos dourados' 'estrela do sul'
#  'coromandel' 'guarda mor' 'irai de minas' 'romaria' 'douradoquara'
#  'paracatu' 'unai' 'urucuia' 'bonfinopolis de minas' 'buritis' 'dom bosco'
#  'cabeceira grande' 'riachinho' 'arinos' 'formoso' 'uruana de minas'
#  'natalandia' 'chapada gaucha' 'serra bonita' 'luizlandia do oeste'
#  'patos de minas' 'presidente olegario' 'lagoa grande' 'joao pinheiro'
#  'vazante' 'patrocinio' 'sao goncalo do abaete' 'lagoa formosa'
#  'guimarania' 'brasilandia de minas' 'varjao de minas' 'serra do salitre'
#  'lagamar' 'pilar' 'cruzeiro da fortaleza' 'sao joao da serra negra'
#  'canabrava' 'silvano' 'santana de patos' 'brejo bonito'
#  "olhos d'agua do oeste" 'veredas' 'sao gotardo' 'carmo do paranaiba'
#  'tiros' 'rio paranaiba' 'quintinos' 'matutina' 'arapua'
#  'santa rosa da serra' 'guarda dos ferreiros' 'ibia' 'pratinha' 'bambui'
#  'corrego danta' 'iguatama' 'campos altos' 'medeiros'
#  'senador modestino goncalves' 'diamantina' 'serro'
#  'sao goncalo do rio preto' 'datas' 'rio vermelho' 'milho verde' 'gouveia'
#  'alvorada de minas' 'senador mourao' 'felicio dos santos' 'gouvea'
#  'serra azul de minas' 'couto de magalhaes de minas'
#  'santo antonio do itambe' 'presidente kubitschek' 'sao joao da chapada'
#  'sao goncalo do rio das pedras' 'desembargador otoni' 'pedra menina'
#  'varzea da palma' 'pirapora' 'lassance' 'tres marias' 'corinto'
#  'buritizeiro' 'santo hipolito' 'buenopolis' 'sao romao' 'augusto de lima'
#  'joaquim felicio' 'santa fe de minas' 'monjolos' 'guaicui' 'andrequice'
#  'presidente juscelino' 'sao joao do pacui' 'jequitai' 'brasilia de minas'
#  'campo azul' 'olhos d agua' 'japonvar' 'bocaiuva' 'ponto chique'
#  'icarai de minas' 'alvacao' 'ibiai' 'francisco dumont' "olhos d'agua"
#  'patis' 'ubai' 'lagoa dos patos' 'sao joao da lagoa' 'coracao de jesus'
#  'claro dos pocoes' 'luislandia' 'mirabela' 'engenheiro navarro'
#  'guaraciama' 'claro dos pocões' 'pintopolis' 'luiz pires de minas'
#  'bentopolis de minas' 'montes claros' 'janauba' 'januaria'
#  'sao joao da ponte' 'lontra' 'manga' 'varzelandia' 'sao joao das missoes'
#  'itacarambi' 'bonito de minas' 'montalvania' 'cacarema'
#  'pedras de maria da cruz' 'ibiracatu' 'capitao eneas' 'miravania'
#  'juvenilia' 'matias cardoso' 'verdelandia' 'sao sebastiao dos pocoes'
#  'sao joao das missões' 'nova esao pauloeranca' 'conego marinho'
#  'vila nova de minas' 'rio pardo de minas' 'taiobeiras' 'mato verde'
#  'serranopolis de minas' 'jaiba' 'porteirinha' 'berizal'
#  'vargem grande do rio pardo' 'salinas' 'itacambira' 'monte azul'
#  'mamonas' 'esao pauloinosa' 'riacho dos machados' 'catuti' 'grao mogol'
#  'botumirim' 'francisco sa' 'fruta de leite' 'padre carvalho'
#  'novorizonte' 'nova porteirinha' 'santa cruz de salinas' 'rubelita'
#  'cristalia' 'montezuma' 'curral de dentro' 'indaiabira' 'juramento'
#  'ninheira' 'gameleiras' 'pai pedro' 'glaucilandia' 'josenopolis'
#  'adao colares' 'santo antonio do retiro' 'catuni' 'tocandira'
#  'barreiro branco' 'itamarandiba' 'capelinha' 'virgem da lapa' 'aracuai'
#  'minas novas' 'malacacheta' 'itaobim' 'coronel murta' 'chapada do norte'
#  'jose goncalves de minas' 'francisco badaro' 'medina' 'comercinho'
#  'angelandia' 'carbonita' 'jenipapo de minas' 'ponto dos volantes'
#  'setubinha' 'franciscopolis' 'veredinha' 'berilo' 'aricanduva'
#  'leme do prado' 'itinga' 'engenheiro schnoor' 'tuparece'
#  'agua branca de minas' 'cacaratiba' 'santa maria do suacui' 'pecanha'
#  'guanhaes' 'sardoa' 'sao jose do jacuri' 'santa efigenia de minas'
#  'gonzaga' 'sao joao evangelista' 'sabinopolis' 'divinolandia de minas'
#  'sao pedro do suacui' 'paulistas' 'materlandia' 'jose raydan'
#  'virginopolis' 'coroaci' 'coluna' 'virgolandia' 'sao jose da safira'
#  'agua boa' 'senhora do porto' 'correntinho' 'frei lagonegro'
#  'sao sebastiao do maranhao' 'sao geraldo da piedade' 'nacip raydan'
#  'sapucaia de guanhaes' 'sao geraldo do baguari' 'nelson de sena'
#  'conceicao de tronqueiras' 'teofilo otoni' 'aguas formosas' 'pote'
#  'joaima' 'nanuque' 'bertopolis' 'novo cruzeiro' 'padre paraiso'
#  'itambacuri' 'itaipe' 'vila pereira' 'monte formoso' 'carai'
#  'frei gasao pauloar' 'fronteira dos vales' 'machacalis' 'ladainha'
#  'novo oriente de minas' 'serra dos aimores' 'ouro verde de minas']
# ['campanario' 'carlos chagas' 'felisburgo' 'santa helena de minas' 'pavao'
#  'umburatiba' 'ataleia' 'catuji' 'queixada' 'crisolita' 'jampruca'
#  'nova santa luzia' 'ponto do marambaia' 'concordia de mucuri'
#  'sao jose do divino' 'presidente pena' 'pedro versiani' 'marambainha'
#  'mucuri' 'epaminondas otoni' 'topazio' 'jequitinhonha' 'pedra azul'
#  'almenara' 'mata verde' 'jordania' 'aguas vermelhas' 'salto da divisa'
#  'divisopolis' 'santo antonio do jacinto' 'jacinto' 'rubim'
#  'cachoeira de pajeu' 'bandeira' 'palmopolis' 'rio do prado'
#  'santa maria do salto' 'avai do jacinto' 'divisa alegre'
#  'estrela de jordania' 'itapiru' 'dois de abril' 'salvador' 'salvador '
#  'lauro de freitas' 'madre de deus' 'abrantes' "dias d'avila" 'camacari'
#  'monte gordo' 'catu de abrantes' 'dias davila' 'dias d avila'
#  'barra do jacuipe' 'arembepe' 'monte gordo (camacari) distrito'
#  'simões filho' 'simoes filho' 'sao sebastiao do passe' 'passe'
#  'menino jesus' 'passagem dos teixeiras' 'sao francisco do conde'
#  'feira de santana' 'santo estevao' 'tanquinho' 'antonio cardoso'
#  'conceicao do jacuipe' 'santo amaro' 'amelia rodrigues'
#  'coracao de maria' 'saubara' 'irara' 'terra nova' 'santanopolis' 'acupe'
#  'cruz das almas' 'cachoeira' 'conceicao da feira' 'sao felix' 'muritiba'
#  'governador mangabeira' 'sao goncalo dos campos'
#  'cabaceiras do paraguacu' 'nazare' 'itaparica' 'maragogipe'
#  'salinas da margarida' 'aratuipe' 'jaguaripe' 'sao roque do paraguacu'
#  'santo antonio de jesus' 'conceicao do almeida' 'sao miguel das matas'
#  'sapeacu' 'castro alves' 'rafael jambeiro' 'sao felipe' 'santa terezinha'
#  'varzedo' 'santa teresinha' 'muniz ferreira' 'dom macedo costa' 'mairi'
#  'capim grosso' 'ipira' 'capela do alto alegre' 'riachao do jacuipe'
#  'pe de serra' 'pintadas' 'nova fatima' 'baixa grande' 'varzea nova'
#  'gaviao' 'sao jose do jacuipe' 'serra preta' 'varzea da roca' 'anguera'
#  'ipecaeta' 'jacobina' 'serrolandia' 'ponto novo' 'ourolandia'
#  'antonio goncalves' 'miguel calmon' 'campo formoso' 'quixabeira'
#  'filadelfia' 'pindobacu' 'caem' 'varzea do poco' 'umburanas' 'mirangaba'
#  'saude' 'caldeirao grande' 'morro do chapeu' 'cafarnaum'
#  'mulungu do morro' 'canarana' 'tapiramuta' 'piritiba' 'barro alto'
#  'mundo novo' 'salobro' 'irece' 'joao dourado' 'central' 'uibai'
#  'presidente dutra' 'barra do mendes' 'lapao' 'america dourada' 'ibitita'
#  'ibipeba' 'jussara' 'sao gabriel' 'vitoria da conquista' 'barra do choca'
#  'ribeirao do largo' 'caatiba' 'tremedal' 'itambe' 'belo campo'
#  'candido sales' 'anage' 'encruzilhada' 'caraibas' 'lucaia' 'jequie'
#  'iguai' 'jitauna' 'pocoes' 'pocões' 'itagi' 'boa nova'
#  'bom jesus da serra' 'ibicui' 'lafaiete coutinho' 'nova canaa' 'catingal'
#  'mirante' 'manoel vitorino' 'aiquara' 'caetanos' 'iguaibi' 'jaguaquara'
#  'maracas' 'itirucu' 'milagres' 'nova itarana' 'brejoes' 'irajuba'
#  'amargosa' 'elisio medrado' 'santa ines' 'cravolandia' 'planaltino'
#  'itaquara' 'ubaira' 'lajedo do tabocal' 'apuarema' 'engenheiro franca'
#  'brejões' 'itubera' 'mutuipe' 'wenceslau guimaraes' 'gandu' 'itamari'
#  'presidente tancredo neves' 'camamu' 'teolandia' 'taperoa' 'igrapiuna'
#  'nilo pecanha' 'morro de sao paulo' 'nova ibia' 'laje' 'pirai do norte'
#  'jiquirica' 'jequirica' 'cairu' 'ibirataia' 'ibirapitanga' 'dario meira'
#  'itacare' 'ipiau' 'itagiba' 'marau' 'ubata' 'barra do rocha' 'gongogi'
#  'ubaitaba' 'ilheus' 'itabuna' 'buerarema' 'coaraci' 'itajuipe' 'urucuca'
#  'una' 'sao jose da vitoria' 'jussari' 'almadina' 'itapitanga'
#  'aurelino leal' 'barro preto' 'arataca' 'governador lomanto junior'
#  'itarantim' 'itororo' 'itapetinga' 'potiragua' 'firmino alves' 'macarani'
#  'ibicarai' 'floresta azul' 'maiquinique' 'rio do meio' 'itape'
#  'santa cruz da vitoria' 'itaju do colonia' 'eunapolis' 'porto seguro'
#  'canavieiras' 'itamaraju' 'trancoso' 'belmonte' "arraial d'ajuda"
#  'camacan' 'jucurucu' 'santa cruz cabralia' 'itabela' 'pau brasil'
#  'itagimirim' 'arraial d ajuda' 'mascote' 'guaratinga' 'itapebi'
#  'teixeira de freitas' 'medeiros neto' 'itanhem' 'caravelas' 'nova vicosa'
#  'prado' 'cumuruxatiba' 'itabatan' 'ibirapua' 'posto da mata' 'itabata'
#  'alcobaca' 'ibiraja' 'batinga' 'lajedao' 'itabatan (mucuri)' 'vereda'
#  'rio de contas' 'brumado' 'malhada de pedras'
#  'livramento de nossa senhora' 'paramirim' 'erico cardoso']
# ['aracatu' 'dom basilio' 'itaquarai' 'piripa' 'maetinga' 'condeuba'
#  'presidente janio quadros' 'rio do antonio' 'mortugaba' 'cordeiros'
#  'guajeru' 'pindai' 'jacaraci' 'cacule' 'candiba' 'urandi' 'ibiassuce'
#  'licinio de almeida' 'tauape' 'irundiara' 'guanambi' 'carinhanha' 'iuiu'
#  'malhada' 'igapora' 'caetite' 'matina' 'feira da mata'
#  'palmas de monte alto' 'riacho de santana' 'lagoa real'
#  'sebastiao laranjeiras' 'maniacu' 'macaubas' 'tanque novo' 'botupora'
#  'ibipitanga' 'caturama' 'boquira' 'rio do pires' 'ibiajara' 'jussiape'
#  'contendas do sincora' 'barra da estiva' 'ituacu' 'tanhacu' 'abaira'
#  'boninal' 'piata' 'ibitiara' 'iramaia' 'ibicoara' 'itaete' 'mucuge'
#  'marcionilio souza' 'inubia' 'bonito' 'ruy barbosa' 'nova redencao'
#  'itaberaba' 'iacu' 'macajuba' 'boa vista do tupim' 'utinga' 'itatim'
#  'andarai' 'ubiraita' 'joao amaro' 'lajedinho' 'ibiquera'
#  'nova redencao bahia' 'seabra' 'wagner' 'palmeiras' 'lencois' 'iraquara'
#  'souto soares' 'iraporanga' 'barra' 'buritirama' 'santa rita de cassia'
#  'muquem de sao francisco' 'muquem do sao francisco' 'mansidao' 'remanso'
#  'pilao arcado' 'campo alegre de lourdes'
#  'campo alegre de lourdes, bahia, brasil' 'casa nova' 'sento se'
#  'santana do sobrado' 'xique xique' 'itaguacu da bahia' 'gentio do ouro'
#  'oliveira dos brejinhos' 'paratinga' 'brotas de macaubas' 'morpara'
#  'ibotirama' 'ipupiara' 'correntina' 'sao felix do coribe'
#  'serra do ramalho' 'bom jesus da lapa' 'santa maria da vitoria' 'cocos'
#  'coribe' 'sitio do mato' 'santana' 'serra dourada' 'brejolandia'
#  'tabocas do brejo velho' 'luis eduardo magalhaes' 'barreiras'
#  'sao desiderio' 'baianopolis' 'sitio grande' 'roda velha' 'catolandia'
#  'formosa do rio preto' 'angical' 'riachao das neves' 'wanderley'
#  'cristopolis' 'cotegipe' 'alagoinhas' 'aramari' 'pojuca' 'entre rios'
#  'catu' 'pedrao' 'agua fria' 'aracas' 'ouricangas' 'boa uniao'
#  'mata de sao joao' 'acu da torre' 'itanagra' 'conde' 'rio real'
#  'esao paulolanada' 'apora' 'acajutiba' 'cardeal da silva' 'jandaira'
#  'itamira' 'novo triunfo' 'cicero dantas' 'nova soure' 'fatima' 'antas'
#  'cipo' 'inhambupe' 'paripiranga' 'ribeira do pombal' 'heliopolis'
#  'olindina' 'banzae' 'itapicuru' 'ribeira do amparo' 'crisopolis'
#  'adustina' 'sao joao da fortaleza' 'satiro dias' 'euclides da cunha'
#  'jeremoabo' 'canudos' 'coronel joao sa' 'santa brigida' 'pedro alexandre'
#  'sitio do quinto' 'paulo afonso' 'gloria' 'rodelas' 'abare' 'chorrocho'
#  'macurure' 'barra do tarrachil' 'ibo' 'serrinha' 'barrocas' 'tucano'
#  'retirolandia' 'araci' 'conceicao do coite' 'teofilandia' 'ichu'
#  'biritinga' 'candeal' 'salgadalia' 'lamarao' 'cansancao' 'itiuba'
#  'valente' 'santaluz' 'monte santo' 'queimadas' 'quijingue' 'algodões'
#  'nordestina' 'juazeiro' 'sobradinho' 'jaguarari' 'senhor do bonfim'
#  'uaua' 'curaca' 'andorinha' 'carnaiba do sertao' 'aracaju' 'riachuelo'
#  'nossa senhora do socorro' 'barra dos coqueiros' "itaporanga d'ajuda"
#  'sao cristovao' 'santo amaro das brotas' 'pirambu' 'laranjeiras'
#  'umbauba' 'estancia' 'itabaianinha' 'cristinapolis' 'tomar do geru'
#  'araua' 'santa luzia do itanhy' 'indiaroba' 'tobias barreto' 'boquim'
#  'salgado' 'pedrinhas' 'riachao do dantas' 'lagarto' 'simao dias'
#  'poco verde' 'malhador' 'campo do brito' 'ribeiropolis' 'frei paulo'
#  'macambira' 'pinhao' 'carira' 'moita bonita' 'sao miguel do aleixo'
#  'nossa senhora aparecida' 'areia branca' 'nossa senhora das dores'
#  'nossa senhora da gloria' 'divina pastora' 'siriri'
#  'monte alegre de sergipe' 'feira nova' 'cumbe' 'santa rosa de lima'
#  'aquidaba' 'carmopolis' 'rosario do catete' 'capela' 'maruim'
#  'general maynard' 'muribeca' 'porto da folha' 'caninde de sao francisco'
#  'canhoba' 'poco redondo' 'nossa senhora de lourdes' 'graccho cardoso'
#  'gararu' 'neopolis' 'propria' 'pacatuba' 'malhada dos bois'
#  'ilha das flores' 'brejo grande' 'japoata' 'cedro de sao joao'
#  'japaratuba' 'santana do sao francisco' 'telha' 'amparo de sao francisco'
#  'recife' 'olinda' 'natal' 'abreu e lima' 'igarassu' 'aracoiaba'
#  'itapissuma' 'ilha de itamaraca' 'itamaraca' 'jaboatao dos guararapes'
#  'jaboatao dos gurarapes' 'cabo de santo agostinho' 'camaragibe'
#  'sao lourenco da mata' 'nossa senhora da luz' 'moreno' 'caruaru'
#  'belo jardim' 'toritama' 'sao caitano' 'brejo da madre de deus'
#  'santa cruz do capibaribe']
# ['riacho das almas' 'tacaimbo' 'serra do vento' 'fazenda nova' 'jatauba'
#  'pesqueira' 'garanhuns' 'sanharo' 'pedra' 'alagoinha' 'venturosa' 'pocao'
#  'sao bento do una' 'bom conselho' 'saloa' 'jupi' 'aguas belas'
#  'capoeiras' 'caetes' 'calcado' 'ibirajuba' 'lajedo' 'cachoeirinha'
#  'correntes' 'lagoa do ouro' 'brejao' 'terezinha' 'iati' 'paranatama'
#  'jucati' 'palmeirina' 'rainha isabel' 'canhotinho' 'maraial' 'catende'
#  'altinho' 'sao joao' 'panelas' 'quipapa' 'jurema' 'cupira' 'agrestina'
#  'belem de maria' 'sao benedito do sul' 'lagoa dos gatos'
#  'santo antonio das queimadas' 'jaqueira' 'batateira' 'angelim' 'cruzes'
#  'laje grande' 'ipojuca' 'agua preta' 'ribeirao' 'escada' 'barreiros'
#  'xexeu' 'palmares' 'tamandare' 'rio formoso' 'sirinhaem' 'amaraji'
#  'nossa senhora do o' 'joaquim nabuco' 'sao jose da coroa grande' 'cortes'
#  'gameleira' 'camela' 'vitoria de santo antao' 'barra de guabiraba'
#  'bezerros' 'gravata' 'gloria do goita' 'cha grande'
#  'camocim de sao felix' 'sao joaquim do monte' 'saire' 'salgadinho'
#  'pombos' 'passira' 'pirituba' 'cumaru' 'frei miguelinho'
#  'taquaritinga do norte' 'surubim' 'vertentes' 'limoeiro' 'orobo'
#  'joao alfredo' 'machados' 'vertente do lerio' 'santa maria do cambuca'
#  'bizarra' 'casinhas' 'carpina' 'paudalho' 'sao vicente ferrer' 'alianca'
#  'timbauba' 'lagoa do carro' 'nazare da mata' 'ferreiros' 'cha de alegria'
#  'buenos aires' 'tracunhaem' 'vicencia' 'macaparana' 'lagoa do itaenga'
#  'condado' 'itaquitinga' 'camutanga' 'salgueiro' 'oroco' 'parnamirim'
#  'moreilandia' 'cabrobo' 'cedro' 'verdejante' 'granito' 'serrita'
#  'santa filomena' 'ipubi' 'exu' 'araripina' 'trindade' 'bodoco' 'ouricuri'
#  'santa cruz' 'petrolina' 'santa maria da boa vista' 'dormentes' 'afranio'
#  'rajada' 'jatoba' 'carnaubeira da penha' 'petrolandia'
#  'belem do sao francisco' 'belem de sao francisco' 'tacaratu' 'itacuruba'
#  'arcoverde' 'buique' 'tupanatinga' 'inaja' 'manari' 'itaiba' 'ibimirim'
#  'sertania' 'custodia' 'betania' 'tabira' 'itapetim' 'tuparetama'
#  'sao jose do egito' 'brejinho' 'solidao' 'santa cruz da baixa verde'
#  'flores' 'afogados da ingazeira' 'caraiba' 'triunfo' 'carnaiba'
#  'jabitaca' 'ingazeira' 'iguaraci' 'quixada' 'ibitiranga' 'quixaba'
#  'serra talhada' 'sao jose do belmonte' 'mirandiba' 'calumbi' 'maceio'
#  'maceia³' 'barra de sao miguel' 'rio largo' 'marechal deodoro' 'satuba'
#  'santa luzia do norte' 'coqueiro seco' 'coruripe' 'feliz deserto'
#  'teotonio vilela' 'junqueiro' 'igreja nova' 'sao miguel dos campos'
#  'luziapolis' 'piacabucu' 'jequia da praia' 'roteiro' 'campo alegre'
#  'porto real do colegio' 'poxim' 'limoeiro de anadia' 'arapiraca'
#  'feira grande' 'craibas' 'lagoa da canoa' 'coite do noia' 'traipu'
#  'girau do ponciano' 'vila sao francisco' 'olho dagua grande' 'sao bras'
#  "olho d'agua grande" 'delmiro gouveia' 'pao de acucar' 'batalha'
#  "olho d'agua das flores" 'piranhas' 'olho d agua das flores'
#  'sao jose da tapera' 'agua branca' 'jaramataia' 'monteiropolis'
#  'pariconha' 'jacare dos homens' "olho d'agua do casado"
#  'santana do ipanema' 'poco das trincheiras' 'dois riachos' 'inhapi'
#  'mata grande' 'maravilha' 'major isidoro' 'cacimbinhas' 'canapi'
#  'olivenca' 'carneiros' 'senador rui palmeira' 'igaci'
#  'estrela de alagoas' 'palmeira dos indios' 'boca da mata' 'maribondo'
#  'belem' "tanque d'arca" 'atalaia' 'anadia' 'taquarana' 'cha preta'
#  'cajueiro' 'paulo jacinto' 'quebrangulo' 'pindoba' 'mar vermelho'
#  'branquinha' 'santana do mundau' 'uniao dos palmares' 'sao jose da laje'
#  'ibateguara' 'murici' 'maragogi' 'sao luis do quitunde' 'joaquim gomes'
#  'japaratinga' 'novo lino' 'sao miguel dos milagres'
#  'matriz de camaragibe' 'porto calvo' 'paripueira' 'colonia leopoldina'
#  'barra de santo antonio' 'porto de pedras' 'flexeiras'
#  'passo de camaragibe' 'jacuipe' 'messias' 'jundia' 'joao pessoa' 'areial'
#  'esao pauloeranca' 'cabedelo' 'barra de santa rosa' 'lagoa seca' 'cuite'
#  'soledade' 'picui' 'campina grande' 'pedra lavrada' 'cubati'
#  'alagoa nova' 'boa vista' 'pocinhos' 'sossego' 'nova floresta'
#  'massaranduba' 'frei martinho' 'barauna' 'damiao' 'montadas' 'puxinana'
#  'sao sebastiao de lagoa de roca' 'matinhas' 'nova palmeira' 'guarabira'
#  'araruna' 'cuitegi' 'mamanguape' 'rio tinto']
# ['jacarau' 'cacimba de dentro' 'mataraca' 'caicara' 'bananeiras' 'aracagi'
#  'cuite de mamanguape' 'serra da raiz' 'itapororoca' 'solanea'
#  'pirpirituba' 'capim' 'dona ines' 'curral de cima' 'piloezinhos'
#  'logradouro' 'duas estradas' 'lagoa de dentro' 'pedro regis'
#  'casserengue' 'pilõezinhos' 'pedras de fogo' 'santa rita' 'inga' 'sape'
#  'bayeux' 'sao miguel de taipu' 'areia' 'riachao do bacamarte'
#  'alagoa grande' 'serra redonda' 'mogeiro' 'caapora' 'arara' 'lucena'
#  'serraria' 'algodao de jandaira' 'remigio' 'mulungu' 'itatuba' 'pilões'
#  'mari' 'gurinhem' 'caldas brandao' 'juripiranga' 'sobrado' 'alhandra'
#  'juarez tavora' 'salgado de sao felix' 'cruz do esao pauloirito santo'
#  'pitimbu' 'piloes' 'sao jose dos ramos' 'santa cecilia de umbuzeiro'
#  'santa cecilia' 'boqueirao' 'natuba' 'umbuzeiro' 'fagundes' 'aroeiras'
#  'sao jose da mata' 'riacho de santo antonio' 'cabaceiras'
#  'barra de santana' 'sao domingos do cariri' 'alcantil' 'sume'
#  'serra branca' 'monteiro' 'sao jose dos cordeiros' 'ouro velho'
#  'sao joao do cariri' 'camalau' 'congo' 'zabele' 'parari'
#  'sao joao do tigre' 'coxixola' 'pindurao' 'santa luzia do cariri'
#  'junco do serido' 'livramento' 'tenorio' 'varzea' 'sao mamede'
#  'juazeirinho' 'cacimbas' 'desterro' 'assuncao' 'gurjao'
#  'sao jose do sabugi' 'patos' 'aguiar' 'tavares' 'princesa isabel'
#  'nova olinda' 'teixeira' 'imaculada' 'santana dos garrotes' "mae d'agua"
#  'pedra branca' "olho d'agua" 'juru' 'sao jose do bonfim' 'malta'
#  'coremas' 'sao jose de caiana' 'pianco' 'matureia' 'igaracy'
#  'sao jose de princesa' 'catingueira' 'sao jose de esao pauloinharas'
#  'areia de baraunas' 'vista serrana' 'sao bentinho' 'catole do rocha'
#  'sousa' 'pombal' 'brejo do cruz' 'sao bento' 'riacho dos cavalos'
#  'brejo dos santos' 'marizopolis' 'sao jose da lagoa tapada' 'lagoa'
#  'sao jose do brejo do cruz' 'mato grosso' 'lastro' 'jerico' 'nazarezinho'
#  'belem do brejo do cruz' 'cajazeiras' 'serra grande' 'carrapateira'
#  'sao joao do rio do peixe' 'manaira' 'uirauna' 'diamante'
#  'santana de mangueira' 'sao jose de piranhas' 'cachoeira dos indios'
#  'ibiara' 'bernardino batista' 'bonito de santa fe' 'poco dantas'
#  'bom jesus' 'santa helena' 'poco de jose de moura' 'monte horebe'
#  'joca claudino' 'sao jose de mipibu' 'esao pauloirito santo' 'goianinha'
#  'nisia floresta' 'vila flor' 'baia formosa' 'canguaretama' 'tibau do sul'
#  'montanhas' 'arez' 'pedro velho' 'pipa' 'macaiba'
#  'sao goncalo do amarante' 'santo antonio' 'serra de sao bento'
#  'sao jose do campestre' 'boa saude' 'nova cruz' 'jacana' 'tangara'
#  'campo redondo' 'coronel ezequiel' "lagoa d'anta" 'lajes pintadas'
#  'passa e fica' 'serra caiada' 'japi' 'monte das gameleiras'
#  'sao bento do trairi' 'lagoa salgada' 'senador eloi de souza' 'jucurutu'
#  'sao jose do serido' 'parelhas' 'currais novos' 'lagoa nova'
#  'jardim do serido' 'caico' 'jardim de piranhas' 'florania' 'acari'
#  'sao joao do sabugi' 'tenente laurentino cruz' 'sao fernando' 'cruzeta'
#  'santana do serido' 'carnauba dos dantas' 'equador'
#  'serra negra do norte' 'ipueira' 'cerro cora' 'timbauba dos batistas'
#  'lagoa de velhos' 'sao paulo do potengi' 'sao tome' 'ielmo marinho'
#  'serra da tapuia' 'barcelona' 'sitio novo' 'santana do matos' 'guamare'
#  'fernando pedroza' 'sao miguel do gostoso' 'alto do rodrigues' 'angicos'
#  'touros' 'ceara mirim' 'joao camara' 'macau' 'caicara do rio do vento'
# ...
#  'bom sucesso do sul' 'cruzeiro do iguacu' 'mariopolis' 'vitorino'
#  'sao jorge do oeste' 'honorio serpa' 'itapejara d oeste'
#  'coronel domingos soares' 'dois irmaos' 'sao roque do chopim'
#  'francisco beltrao' 'dois vizinhos' 'salto do lontra'
#  'nova prata do iguacu' 'ampere' 'renascenca' 'marmeleiro' 'eneas marques'
#  'nova esao pauloeranca do sudoeste' 'santa izabel do oeste'
#  'boa esao pauloeranca do iguacu' 'salgado filho' 'flor da serra do sul'
#  'manfrinopolis' 'santo antonio do sudoeste' 'bom jesus do sul'
#  'capitao leonidas marques' 'pranchita' 'pinhal de sao bento'
#  'boa vista da aparecida' "perola d'oeste" 'barracao'
#  'bela vista da caroba' 'alto alegre do iguacu' 'perola doeste'
#  'foz do iguacu' 'ceu azul' 'medianeira' 'missal' 'sao miguel do iguacu'
#  'diamante d oeste' 'santa tereza do oeste' 'formosa do oeste'
#  'santa terezinha de itaipu' "diamante d'oeste" 'matelandia'
#  'vera cruz do oeste' 'itaipulandia' 'jesuitas' 'sao jose das palmeiras'
#  'serranopolis do iguacu' 'rio do salto' 'ramilandia' 'sede alvorada'
#  'sao jose do itavo' 'lindoeste' 'iracema do oeste' 'aurora do iguacu'
#  'marechal candido rondon' 'palotina' 'assis chateaubriand'
#  'quatro pontes' 'nova santa rosa' 'tupassi' 'novo sarandi'
#  'ouro verde do oeste' 'pato bragado' 'bragantina' 'maripa' 'vila nova'
#  'novo sobradinho' 'mercedes' 'santa rita do oeste' 'porto mendes'
#  'sao pedro do iguacu' 'entre rios do oeste' 'doutor oliveira castro'
#  'sao camilo' 'dez de maio' "encantado d'oeste" 'londrina' 'sertanopolis'
#  'porecatu' 'primeiro de maio' 'florestopolis' 'tamarana'
#  'bela vista do paraiso' 'cambe' 'alvorada do sul' 'paiquere'
#  'nova santa barbara' 'assai' 'nova america da colina' 'ibipora'
#  'santa cecilia do pavao' 'sao sebastiao da amoreira' 'urai' 'jataizinho'
#  'sao jeronimo da serra' 'rancho alegre' 'cruzeiro do norte'
#  'cornelio procopio' 'congonhinhas' 'cambara' 'andira' 'santa amelia'
#  'barra do jacare' 'sertaneja' 'leopolis' 'santa mariana' 'itambaraca'
#  'santo antonio do paraiso' 'panema' 'joaquim tavora' 'jacarezinho'
#  'santo antonio da platina' 'quatigua' 'ribeirao do pinhal' 'carlopolis'
#  'ribeirao claro' 'conselheiro mairinck' 'guapirama' 'abatia'
#  'jundiai do sul' 'lupionopolis' 'rolandia' 'santo inacio' 'itaguaje'
#  'colorado' 'sao martinho' 'jaguapita' 'centenario do sul'
#  'nossa senhora das gracas' 'prado ferreira' 'miraselva' 'cafeara'
#  'bentopolis' 'astorga' 'arapongas' 'florida' 'lobato' 'iguaracu'
#  'santa fe' 'munhoz de melo' 'sabaudia' 'angulo' 'icara' 'santa zelia'
#  'apucarana' 'jardim alegre' 'maua da serra' 'cruzmaltina' 'vila reis'
#  'ivaipora' 'rosario do ivai' 'marilandia do sul' 'faxinal'
#  'rio branco do ivai' 'ariranha do ivai' 'california' 'lidianopolis'
#  'rio bom' 'grandes rios' 'cambira' 'pirapo']
# ['novo itacolomi' 'godoy moreira' 'marialva' 'jandaia do sul' 'marumbi'
#  'mandaguari' 'borrazopolis' 'sao pedro do ivai' 'lunardelli'
#  'barbosa ferraz' 'corumbatai do sul' 'sao joao do ivai' 'kalore' 'fenix'
#  'luar' 'aquidaban' 'ubauna' 'maringa' 'mandaguacu' 'paicandu' 'sarandi'
#  'sao jorge do ivai' 'doutor camargo' 'ourizona' 'ivatuba' 'florai'
#  'presidente castelo branco' 'pulinopolis' 'cianorte' 'peabiru' 'luiziana'
#  'engenheiro beltrao' 'iretama' 'quinta do sol' 'sao manoel do parana'
#  'ivailandia' 'terra boa' 'vidigal' 'campo mourao' 'janiopolis'
#  'moreira sales' 'roncador' 'goioere' 'mambore' 'juranda'
#  'campina da lagoa' 'nova cantu' "rancho alegre d'oeste"
#  'quarto centenario' 'farol' 'rancho alegre d oeste' "parana d'oeste"
#  'tapejara' 'mariluz' 'tuneiras do oeste' 'cruzeiro do oeste'
#  'maria helena' 'sao silvestre' 'altonia' 'umuarama' 'perola' 'guaipora'
#  'sao jorge do patrocinio' 'xambre' 'brasilandia do sul' 'ivate'
#  'icaraima' 'alto piquiri' 'perobal' 'cafezal do sul' 'francisco alves'
#  'serra dos dourados' 'esao pauloeranca nova' 'santa eliza' 'uniflor'
#  'paranacity' 'paranapoema' 'jardim olinda' 'alto parana' 'paranavai'
#  'sao carlos do ivai' 'paraiso do norte' 'sao joao do caiua' 'tamboara'
#  'santo antonio do caiua' 'nova alianca do ivai' 'graciosa' 'guairaca'
#  'cidade gaucha' 'terra rica' 'rondon' 'planaltina do parana' 'amapora'
#  'guaporema' 'adhemar de barros' 'santa cruz de monte castelo'
#  'itauna do sul' 'nova londrina' 'loanda' 'marilena' 'querencia do norte'
#  'santa isabel do ivai' 'porto rico' 'santa monica' 'sao pedro do parana'
#  'diamante do norte' 'porto sao jose' 'sao jose do ivai' 'florianopolis'
#  'florian&oacute;polis' 'floripa' 'palhoca' 'santo amaro da imperatriz'
#  'governador celso ramos' 'biguacu' 'sao pedro de alcantara'
#  'aguas mornas' 'guaporanga' 'bombinhas' 'tijucas' 'itapema' 'porto belo'
#  'canelinha' 'nova trento' 'major gercino' 'botuvera' 'itajai'
#  'balneario camboriu' 'navegantes' 'brusque' 'penha' 'balneario picarras'
#  'camboriu' 'barra velha' 'guabiruba' 'ilhota' 'sao joao do itaperiu'
#  'picarras' 'agrolandia' 'alfredo wagner' 'vidal ramos' 'leoberto leal'
#  'paulo lopes' 'garopaba' 'rancho queimado' 'ituporanga' 'atalanta'
#  'angelina' 'imbuia' 'anitapolis' 'sao bonifacio' 'chapadao do lageado'
#  'celso ramos' 'otacilio costa' 'correia pinto' 'anita garibaldi'
#  'sao jose do cerrito' 'capao alto' 'bocaina do sul' 'campo belo do sul'
#  'cerro negro' 'painel' 'videira' 'bom retiro' 'sao joaquim' 'urubici'
#  'urupema' 'rio rufino' 'bom jardim da serra' 'tubarao' 'laguna'
#  'imbituba' 'braco do norte' 'sangao' 'treze de maio' 'sao ludgero'
#  'capivari de baixo' 'imarui' 'jaguaruna' 'armazem' 'rio fortuna'
#  'azambuja' 'pescaria brava' 'gravatal' 'pedras grandes' 'criciuma'
#  'estacao cocal' 'lauro muller' 'orleans' 'nossa senhora de caravaggio'
#  'forquilhinha' 'urussanga' 'sideropolis' 'cocal do sul' 'grao para'
#  'morro da fumaca' 'lauro müller' 'treviso' 'balneario rincao' 'ararangua'
#  'passo de torres' 'balneario arroio do silva' 'jacinto machado' 'meleiro'
#  'santa rosa do sul' 'sao joao do sul' 'sombrio' 'balneario gaivota'
#  'sapiranga' 'timbe do sul' 'ermo' 'maracaja' 'morro grande' 'morro chato'
#  'indaial' 'blumenau' 'rio do sul' 'jose boiteux' 'lontras' 'rio do campo'
#  'laurentino' 'gasao pauloar' 'luiz alves' 'timbo' 'pomerode' 'salete'
#  'benedito novo' 'presidente getulio' 'apiuna' 'ibirama' 'rodeio'
#  'trombudo central' 'pouso redondo' 'doutor pedrinho' 'agronomica'
#  'braco do trombudo' 'witmarsum' 'ascurra' 'taio' 'rio do oeste'
#  'vitor meireles' 'dona emma' 'dalbergia' 'rio dos cedros'
#  'presidente nereu' 'mirim doce' 'joinville' 'sao bento do sul'
#  'rio negrinho' 'araquari' 'sao francisco do sul' 'jaragua do sul'
#  'guaramirim' 'schroeder' 'garuva' 'balneario barra do sul' 'itapoa'
#  'corupa' 'itapocu' 'fragosos' 'mafra' 'itaiopolis' 'papanduva'
#  'residencia fuck' 'canoinhas' 'porto uniao' 'major vieira'
#  'bela vista do toldo' 'irineopolis' 'tres barras' 'santa cruz do timbo'
#  'calmon' 'matos costa' 'cacador' 'fraiburgo' 'curitibanos' 'timbo grande'
#  'ponte alta do norte' 'arroio trinta' 'iomere' 'lebon regis'
#  'salto veloso' 'pinheiro preto' 'sao cristovao do sul' 'rio das antas'
#  'frei rogerio' 'macieira' 'campos novos' 'irani' 'brunopolis'
#  'faxinal dos guedes' 'joacaba' 'piratuba' 'capinzal' 'ponte serrada'
#  'agua doce' 'treze tilias' 'passos maia' "herval d'oeste"
#  'herval d oeste']
# ['monte carlo' 'vargeao' 'ouro' 'abdon batista' 'ibiam' 'jabora'
#  'erval velho' 'zortea' 'ibicare' 'luzerna' 'herval doeste' 'lacerdopolis'
#  "herval d' oeste" 'concordia' 'seara' 'arabuta' 'ita'
#  'presidente castello branco' 'xavantina' 'lindoia do sul'
#  'alto bela vista' 'ipumirim' 'peritiba' 'arvoredo' 'paial' 'serra alta'
#  'xaxim' 'chapeco' 'xanxere' 'palmitos' 'sao joao do oeste' 'sul brasil'
#  'coronel freitas' 'caibi' 'modelo' 'ipora do oeste' 'nova erechim'
#  'formosa do sul' 'mondai' 'saudades' 'ipuacu' 'cunha pora' 'riqueza'
#  'abelardo luz' 'quilombo' 'cunhatai' 'caxambu do sul' 'aguas de chapeco'
#  'tunapolis' 'galvao' 'aguas frias' 'sao miguel da boa vista' 'iraceminha'
#  'guatambu' 'santiago do sul' 'planalto alegre' 'coronel martins'
#  'cordilheira alta' 'uniao do oeste' 'tigrinhos' 'nova itaberaba' 'jupia'
#  'flor do sertao' 'lajeado grande' 'marema' 'sao miguel do oeste'
#  'campo ere' 'sao lourenco do oeste' 'sao jose do cedro' 'princesa'
#  'guaruja do sul' 'santa terezinha do progresso' 'descanso' 'romelandia'
#  'dionisio cerqueira' 'sao bernardino' 'palma sola' 'bandeirante'
#  'porto alegre' 'porto aelgre' 'canoas' 'guaiba' 'sertao santana'
#  'eldorado do sul' 'mariana pimentel' 'sao leopoldo' 'portao'
#  'sapucaia do sul' 'esteio' 'novo hamburgo' 'estancia velha' 'campo bom'
#  'nova hartz' 'ararica' 'morro reuter' 'ivoti' 'lindolfo collor'
#  'santa maria do herval' 'presidente lucena' 'gravatai' 'glorinha'
#  'viamao' 'capao da porteira' 'aguas claras' 'caxias do sul'
#  'carlos barbosa' 'sao marcos' 'farroupilha' 'nova petropolis'
#  'pinhal alto' 'picada cafe' 'nova sardenha' 'jansen' 'arco verde'
#  'fazenda souza' 'nova milano' 'vacaria' 'flores da cunha'
#  'sao jose dos ausentes' 'antonio prado' 'ipe' 'campestre da serra'
#  'monte alegre dos campos' 'nova roma do sul' 'otavio rocha'
#  'muitos capoes' 'nova padua' 'lagoa vermelha' 'nova prata' 'parai'
#  'veranopolis' 'ibiraiaras' 'fagundes varela' 'sao jorge' 'vila flores'
#  'caseiros' 'nova bassano' 'vista alegre do prata' 'cotipora' 'nova araca'
#  'guabiju' 'andre da rocha' 'pinhal da serra' 'protasio alves' 'esmeralda'
#  'cambara do sul' 'jaquirana' 'osvaldo kroeff' 'santo antonio da patrulha'
#  'cidreira' 'tramandai' 'torres' 'capao da canoa' 'palmares do sul'
#  'morrinhos do sul' 'osorio' 'xangri la' 'tres cachoeiras' 'arroio do sal'
#  'capivari do sul' 'rainha do mar' 'balneario pinhal' 'maquine'
#  'capao novo' 'terra de areia' 'dom pedro de alcantara' 'quintao' 'caraa'
#  'itati' 'tres forquilhas' 'xangrila' 'curumim' 'tres coroas' 'canela'
#  'gramado' 'taquara' 'imbe' 'parobe' 'rolante' 'igrejinha' 'riozinho'
#  'salvador do sul' 'sao sebastiao do cai' 'bento goncalves' 'alto feliz'
#  'bom principio' 'roca sales' 'montenegro' 'sao vendelino' 'garibaldi'
#  'marata' 'feliz' 'tupandi' 'coronel pilar' 'capela de santana' 'barao'
#  'sao jose do hortencio' 'monte belo do sul' 'linha nova' 'brochier'
#  'pareci novo' 'vale real' 'boa vista do sul' 'sao jose do sul'
#  'sao pedro da serra' 'vale dos vinhedos' 'pinto bandeira'
#  'poco das antas' 'bom retiro do sul' 'venancio aires' 'teutonia'
#  'estrela' 'taquari' 'imigrante' 'general camara' 'westfalia'
#  'fazenda vilanova' 'mato leitao' 'vale verde' 'paverama' 'tabai'
#  'nova alvorada' 'mucum' 'encantado' 'progresso' 'arvorezinha'
#  'arroio do meio' 'boqueirao do leao' 'santa clara do sul' 'nova brescia'
#  'anta gorda' 'capitao' 'ilopolis' 'doutor ricardo' 'relvado' 'serio'
#  'putinga' 'pouso novo' 'marques de souza' 'canudos do vale' 'itapuca'
#  'coqueiro baixo' 'forquetinha' 'vesao pauloasiano correa' 'travesseiro'
#  'pelotas' 'sao lourenco do sul' 'camaqua' 'dom feliciano' 'capao do leao'
#  'arambare' 'chuvisca' 'cristal' 'morro redondo' 'arroio do padre'
#  'colonia z 3' 'turucu' 'santa vitoria do palmar' 'monte bonito'
#  'sao jose do norte' 'rio grande' 'mostardas' 'chui' 'quinta' 'jaguarao'
#  'arroio grande' 'pedro osorio' 'cerrito' 'herval' 'bage'
#  'pinheiro machado' 'dom pedrito' 'candiota' 'hulha negra' 'piratini'
#  'acegua' 'pedras altas' 'colonia nova' 'cachoeira do sul'
#  'cacapava do sul' 'paraiso do sul' 'santana da boa vista' 'novo cabrais'
#  'cerro branco' 'cortado' 'cangucu' 'rio pardo' 'encruzilhada do sul'
#  'pantano grande' 'passo do sobrado' 'amaral ferrador' 'arroio dos ratos'
#  'charqueadas' 'sao jeronimo' 'tapes' 'barra do ribeiro' 'butia'
#  'minas do leao' 'cerro grande do sul' 'sentinela do sul']
# ['barao do triunfo' 'santa cruz do sul' 'sinimbu' 'vale do sol'
#  'monte alverne' 'herveiras' 'gramado xavier' 'candelaria' 'passa sete'
#  'estrela velha' 'arroio do tigre' 'ibarama' 'segredo'
#  'lagoa bonita do sul' 'itaara' 'dilermando de aguiar' 'silveira martins'
#  'sao martinho da serra' 'faxinal do soturno' 'nova palma' 'restinga seca'
#  'sao joao do polesine' 'formigueiro' 'dona francisca' 'sao sepe'
#  'lavras do sul' 'vila nova do sul' 'santa margarida do sul'
#  'sao vicente do sul' 'sao pedro do sul' 'mata' 'cacequi' 'toropi'
#  'uruguaiana' 'santana do livramento' 'rosario do sul' 'alegrete' 'quarai'
#  "sant'ana do livramento" 'barra do quarai' 'barrado quarai'
#  'sao francisco de assis' 'sao borja' 'manoel viana' 'itaqui' 'macambara'
#  'itacurubi' 'garruchos' 'santiago' 'capao do cipo'
#  'nova esao pauloeranca do sul' 'jaguari' 'unistalda' 'sao luiz gonzaga'
#  'bossoroca' 'santo antonio das missões' 'sao nicolau'
#  'santo antonio das missoes' 'dezesseis de novembro' 'rolador'
#  'sao paulo das missoes' 'cerro largo' 'caibate' 'guarani das missoes'
#  'salvador das missoes' 'roque gonzales' 'sao pedro do butia'
#  'mato queimado' 'guarani das missões' 'salvador das missões'
#  'sao paulo das missões' 'sete de setembro' 'cruz alta' 'jari'
#  'tupancireta' 'julio de castilhos' 'boa vista do cadeado'
#  'fortaleza dos valos' 'joia' 'pinhal grande' 'ivora' 'quevedos'
#  'boa vista do incra' 'ibiruba' 'quinze de novembro' 'panambi'
#  'santa barbara do sul' 'condor' 'pejucara' 'saldanha marinho'
#  'palmeira das missoes' 'seberi' 'cerro grande' 'rodeio bonito'
#  'lajeado do bugre' 'sao jose das missões' 'novo barreiro'
#  'palmeira das missões' 'novo tiradentes' 'sagrada familia'
#  'cristal do sul' 'pinhal' 'jaboticaba' 'boa vista das missoes'
#  'erval seco' 'boa vista das missões' 'sao jose das missoes'
#  'dois irmaos das missões' 'dois irmaos das missoes' 'palmitinho'
#  'frederico westphalen' 'ametista do sul' 'alpestre' 'irai'
#  'vicente dutra' 'pinheirinho do vale' 'taquarucu do sul'
#  'tenente portela' 'santo augusto' 'redentora' 'vista gaucha' 'derrubadas'
#  'campo novo' 'coronel bicaco' 'miraguai' 'braga' 'barra do guarita'
#  'bom progresso' 'sao valerio do sul' 'tres passos' 'tiradentes do sul'
#  'crissiumal' 'esao pauloeranca do sul' 'sede nova' 'padre gonzales'
#  'ijui' 'catuipe' 'santa rosa' 'chiapetta' 'augusto pestana' 'ajuricaba'
#  'inhacora' 'nova ramada' 'bozano' 'coronel barros' 'santo angelo' 'girua'
#  'sao miguel das missoes' 'sao miguel das missões' 'eugenio de castro'
#  'senador salgado filho' 'entre ijuis' 'vitoria das missoes'
#  'vitoria das missões' 'ubiretama' 'tres de maio' 'santo cristo'
#  'campina das missoes' 'nova candelaria' 'boa vista do burica'
#  'porto lucena' 'porto xavier' 'alecrim' 'horizontina' 'tuparendi'
#  'candido godoi' 'doutor mauricio cardoso' 'tucunduva' 'novo machado'
#  'porto maua' 'campina das missões' 'sao jose do inhacora'
#  'porto vera cruz' 'passo fundo' 'ernestina' 'sertao' 'camargo'
#  'nicolau vergueiro' 'vila maria' 'coxilha' 'mato castelhano' 'pontao'
#  'gentil' 'serafina correa' 'vanini' 'guapore' 'santo antonio do palma'
#  'dois lajeados' 'casca' 'sao domingos do sul' 'uniao da serra'
#  'sao valentim do sul' 'montauri' 'ibirapuita' 'fontoura xavier'
#  'sao jose do herval' 'lagoao' 'tio hugo' 'barros cassal' 'victor graeff'
#  'mormaco' 'tunas' 'nao me toque' 'esao pauloumoso' 'tapera' 'selbach'
#  'salto do jacui' 'campos borges' 'lagoa dos tres cantos' 'jacuizinho'
#  'carazinho' 'santo antonio do planalto' 'chapada'
#  'almirante tamandare do sul' 'coqueiros do sul' 'rondinha'
#  'nova boa vista' 'barra funda' 'sao valentim' 'trindade do sul' 'nonoai'
#  'campinas do sul' 'benjamin constant do sul' 'ronda alta'
#  'liberato salzano' 'constantina' 'gramado dos loureiros' 'faxinalzinho'
#  'tres palmeiras' 'cruzaltense' 'novo xingu' 'entre rios do sul'
#  'rio dos indios' 'erechim' 'aratiba' 'barra do rio azul' 'itatiba do sul'
#  'paulo bento' 'tres arroios' 'ponte preta' 'barao de cotegipe'
#  'erval grande' 'mariano moro' 'quatro irmaos' 'severiano de almeida'
#  'sao jose do ouro' 'machadinho' 'sao joao da urtiga'
#  'maximiliano de almeida' 'sananduva' 'viadutos' 'santo expedito do sul'
#  'gaurama' 'cacique doble' 'aurea' 'carlos gomes' 'marcelino ramos'
#  'paim filho' 'tupanci do sul' 'david canabarro' 'ibiaca' 'getulio vargas'
#  'agua santa' 'muliterno' 'estacao' 'charrua' 'ipiranga do sul'
#  'vila langaro' 'ciriaco' 'floriano peixoto' 'erebango'
#  'santa cecilia do sul']

# %%
no_unique_cities =geolocation_df['geolocation_city'].nunique()
no_unique_cities
# Out:
# 5972

# %%
geolocation_df.head(50)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 804356                        75345       -16.766457       -49.434210
# 804643                        75345       -16.758001       -49.435440
# 804612                        75345       -16.767623       -49.426674
# 804572                        75345       -16.789539       -49.469430
# 804534                        75345       -16.756821       -49.435020
# 804389                        75345       -16.766377       -49.437467
# 804509                        75345       -16.766377       -49.437467
# 804359                        75345       -16.765308       -49.429008
# 650614                        38540       -18.486215       -47.404300
# 650597                        38540       -18.480443       -47.404557
# 650593                        38540       -18.484185       -47.402738
# 650587                        38540       -18.482286       -47.405746
# 650560                        38540       -18.491228       -47.404812
# 650484                        38540       -18.471736       -47.405014
# 650550                        38540       -18.471752       -47.405013
# 650541                        38540       -18.487810       -47.404862
# 650650                        38540       -18.479220       -47.403665
# 650451                        38540       -18.491105       -47.398266
# 650556                        38540       -18.487396       -47.400222
# 650655                        38540       -18.489924       -47.404947
# 650677                        38540       -18.483290       -47.407009
# 650733                        38540       -18.487924       -47.404897
# 650735                        38540       -18.486249       -47.398279
# 650812                        38540       -18.369768       -47.459658
# 650829                        38540       -18.482966       -47.403570
# 650881                        38540       -18.485745       -47.402463
# 650894                        38540       -18.486249       -47.398279
# 650921                        38540       -18.369768       -47.459658
# 650967                        38540       -18.487924       -47.404897
# 650979                        38540       -18.481174       -47.403838
# 650986                        38540       -18.470862       -47.405019
# 650991                        38540       -18.481505       -47.403817
# 651008                        38540       -18.479220       -47.403665
# 650673                        38540       -18.480443       -47.404557
# 792708                        72940       -16.195459       -48.709629
# 792723                        72940       -16.196395       -48.712319
# 792704                        72940       -16.196924       -48.706260
# 792518                        72940       -16.191078       -48.710467
# 792676                        72940       -16.194906       -48.704645
# 792658                        72940       -16.191262       -48.713751
# 792609                        72940       -16.189333       -48.712441
# 792601                        72940       -16.194298       -48.711113
# 792751                        72940       -16.193556       -48.707920
# 792557                        72940       -16.190923       -48.710395
# 792702                        72940       -16.200003       -48.705553
# 792756                        72940       -16.194945       -48.710033
# 792670                        72940       -16.197203       -48.710503
# 792370                        72940       -16.192659       -48.713166
# 792457                        72940       -16.200777       -48.705618
# 792405                        72940       -16.180524       -48.708817
#
#            geolocation_city geolocation_state
# 804356      abadia de goias                GO
# 804643      abadia de goias                GO
# 804612      abadia de goias                GO
# 804572      abadia de goias                GO
# 804534      abadia de goias                GO
# 804389      abadia de goias                GO
# 804509      abadia de goias                GO
# 804359      abadia de goias                GO
# 650614  abadia dos dourados                MG
# 650597  abadia dos dourados                MG
# 650593  abadia dos dourados                MG
# 650587  abadia dos dourados                MG
# 650560  abadia dos dourados                MG
# 650484  abadia dos dourados                MG
# 650550  abadia dos dourados                MG
# 650541  abadia dos dourados                MG
# 650650  abadia dos dourados                MG
# 650451  abadia dos dourados                MG
# 650556  abadia dos dourados                MG
# 650655  abadia dos dourados                MG
# 650677  abadia dos dourados                MG
# 650733  abadia dos dourados                MG
# 650735  abadia dos dourados                MG
# 650812  abadia dos dourados                MG
# 650829  abadia dos dourados                MG
# 650881  abadia dos dourados                MG
# 650894  abadia dos dourados                MG
# 650921  abadia dos dourados                MG
# 650967  abadia dos dourados                MG
# 650979  abadia dos dourados                MG
# 650986  abadia dos dourados                MG
# 650991  abadia dos dourados                MG
# 651008  abadia dos dourados                MG
# 650673  abadia dos dourados                MG
# 792708            abadiania                GO
# 792723            abadiania                GO
# 792704            abadiania                GO
# 792518            abadiania                GO
# 792676            abadiania                GO
# 792658            abadiania                GO
# 792609            abadiania                GO
# 792601            abadiania                GO
# 792751            abadiania                GO
# 792557            abadiania                GO
# 792702            abadiania                GO
# 792756            abadiania                GO
# 792670            abadiania                GO
# 792370            abadiania                GO
# 792457            abadiania                GO
# 792405            abadiania                GO

# %%
geolocation_df['geolocation_city'] = geolocation_df['geolocation_city'].apply(lambda x: ' '.join(x.split()))

# %%
geolocation_df = geolocation_df.sort_values(by='geolocation_lat')
geolocation_df.head(50)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 978656                        96255       -33.692616       -53.453972
# 978674                        96255       -33.692504       -53.456158
# 978660                        96255       -33.692491       -53.456402
# 978363                        96255       -33.692291       -53.460274
# 979359                        96255       -33.692255       -53.460853
# 979422                        96255       -33.692196       -53.456586
# 979736                        96255       -33.692177       -53.450862
# 979282                        96255       -33.692136       -53.463279
# 978860                        96255       -33.692136       -53.463279
# 978706                        96255       -33.692047       -53.465099
# 978538                        96255       -33.691699       -53.454030
# 978749                        96255       -33.691673       -53.450672
# 978479                        96255       -33.691673       -53.450672
# 979099                        96255       -33.691643       -53.451511
# 979150                        96255       -33.691608       -53.452208
# 979087                        96255       -33.691550       -53.454576
# 980017                        96255       -33.691550       -53.454576
# 978631                        96255       -33.691499       -53.454217
# 978290                        96255       -33.691445       -53.479988
# 978429                        96255       -33.691424       -53.480155
# 978678                        96255       -33.691424       -53.480155
# 978750                        96255       -33.691424       -53.480155
# 978938                        96255       -33.691424       -53.480155
# 979048                        96255       -33.691423       -53.480161
# 978173                        96255       -33.691423       -53.480161
# 978577                        96255       -33.691423       -53.480161
# 979088                        96255       -33.691418       -53.480201
# 979343                        96255       -33.691403       -53.456535
# 978174                        96255       -33.691314       -53.479898
# 978742                        96255       -33.690989       -53.450778
# 978187                        96255       -33.690955       -53.452161
# 979051                        96255       -33.690729       -53.448653
# 979429                        96255       -33.690729       -53.448653
# 978180                        96255       -33.690559       -53.454766
# 979273                        96255       -33.690522       -53.456478
# 979001                        96255       -33.690360       -53.458753
# 978207                        96255       -33.690223       -53.458747
# 978477                        96255       -33.690223       -53.458747
# 979254                        96255       -33.690171       -53.457083
# 978916                        96255       -33.689766       -53.451953
# 978302                        96255       -33.689565       -53.447144
# 979926                        96255       -33.689565       -53.447144
# 979028                        96255       -33.689056       -53.454752
# 978443                        96255       -33.688890       -53.455771
# 979168                        96255       -33.688788       -53.461195
# 979727                        96255       -33.687775       -53.460201
# 979052                        96255       -33.687674       -53.461337
# 979809                        96255       -33.687519       -53.455843
# 978819                        96255       -33.687519       -53.455843
# 979409                        96255       -33.687487       -53.452017
#
#        geolocation_city geolocation_state
# 978656             chui                RS
# 978674             chui                RS
# 978660             chui                RS
# 978363             chui                RS
# 979359             chui                RS
# 979422             chui                RS
# 979736             chui                RS
# 979282             chui                RS
# 978860             chui                RS
# 978706             chui                RS
# 978538             chui                RS
# 978749             chui                RS
# 978479             chui                RS
# 979099             chui                RS
# 979150             chui                RS
# 979087             chui                RS
# 980017             chui                RS
# 978631             chui                RS
# 978290             chui                RS
# 978429             chui                RS
# 978678             chui                RS
# 978750             chui                RS
# 978938             chui                RS
# 979048             chui                RS
# 978173             chui                RS
# 978577             chui                RS
# 979088             chui                RS
# 979343             chui                RS
# 978174             chui                RS
# 978742             chui                RS
# 978187             chui                RS
# 979051             chui                RS
# 979429             chui                RS
# 978180             chui                RS
# 979273             chui                RS
# 979001             chui                RS
# 978207             chui                RS
# 978477             chui                RS
# 979254             chui                RS
# 978916             chui                RS
# 978302             chui                RS
# 979926             chui                RS
# 979028             chui                RS
# 978443             chui                RS
# 979168             chui                RS
# 979727             chui                RS
# 979052             chui                RS
# 979809             chui                RS
# 978819             chui                RS
# 979409             chui                RS

# %%
pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in c:\users\ros\anaconda\lib\site-packages (0.18.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-Levenshtein
# Out:
# Requirement already satisfied: python-Levenshtein in c:\users\ros\anaconda\lib\site-packages (0.25.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: Levenshtein==0.25.1 in c:\users\ros\anaconda\lib\site-packages (from python-Levenshtein) (0.25.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.8.0 in c:\users\ros\anaconda\lib\site-packages (from Levenshtein==0.25.1->python-Levenshtein) (3.8.1)

# %%
from fuzzywuzzy import process


# Get unique city names

# Group similar city names together
city_clusters = {}
for city in unique_cities2:
    # Find the best match for the current city in the existing clusters
    result = process.extractOne(city, city_clusters.keys())
    
    # Check if a match is found and similarity score is above a threshold
    if result is not None and result[1] > 80:
        best_match, _ = result
        city_clusters[best_match].append(city)
    # Otherwise, create a new cluster for the city
    else:
        city_clusters[city] = [city]

# Now, city_clusters contains clusters of similar city names

# %%
city_clusters
# Out:
# {'sao paulo': ['sao paulo',
#   'sao bernardo do campo',
#   'sao jose dos campos',
#   'sao lourenco da serra',
#   'guarulhos sao paulo',
#   'sao caetano do sul',
#   'sao francisco da praia',
#   'sao luiz do paraitinga',
#   'sao luis do paraitinga',
#   'sao francisco xavier',
#   'sao bento do sapucai',
#   'sao jose do barreiro',
#   'aguas de sao pedro',
#   'sao jose do rio pardo',
#   'sao benedito das areias',
#   'sao joao da boa vista',
#   'sao roque da fartura',
#   'esao pauloirito santo do pinhal',
#   'santa cruz da esao pauloeranca',
#   'sao jose da bela vista',
#   'franca sao paulo',
#   'sao benedito da cachoeirinha',
#   'sao joaquim da barra',
#   'boa esao pauloeranca do sul',
#   'sao jose do rio preto',
#   'sao joao de iracema',
#   'paulo de faria',
#   'sao joao das duas pontes',
#   'asao pauloasia',
#   'sao joao de itaguacu',
#   "sao joao do pau d'alho",
#   'sao joao do pau d alho',
#   'sao joao do pau dalho',
#   'sao joao do pau d%26apos%3balho',
#   'sao miguel arcanjo',
#   'sao pedro do turvo',
#   'esao pauloirito santo do turvo',
#   'esao pauloigao',
#   'sao jose das laranjeiras',
#   'sao joao de meriti',
#   'sao jose do vale do rio preto',
#   'comendador levy gasao pauloarian',
#   'engenheiro paulo de frontin',
#   'sao jose do turvo',
#   'sao joao da barra',
#   'sao jose de uba',
#   'sao jose do ribeirao',
#   'barra de sao joao',
#   'boa esao pauloeranca',
#   'sao pedro da aldeia',
#   'sao joao de vicosa',
#   'sao jose do calcado',
#   'sao jose das torres',
#   'divino de sao lourenco',
#   'sao pedro de rates',
#   'sao gabriel da palha',
#   'sao domingos do norte',
#   'sao joao do sobrado',
#   'sao jorge do tiradentes',
#   'sao joaquim de bicas',
#   'vesao pauloasiano',
#   'sao jose da lapa',
#   'sao jose do acacio',
#   'resao paulolendor',
#   'sao joao do manteninha',
#   'sao geraldo do baixio',
#   'sao felix de minas',
#   'sao jose do itueto',
#   'sao pedro dos ferros',
#   'sao domingos das dores',
#   'sao joao do jacutinga',
#   'sao bras do suacui',
#   'sao bartolomeu',
#   'sao jose dos salgados',
#   'bom desao pauloacho',
#   'sao jose da varginha',
#   'sao domingos do prata',
#   'sao joao da serra',
#   'sao joao del rei',
#   'rio esao pauloera',
#   'sao miguel do anta',
#   'sao joao nepomuceno',
#   'mar de esao pauloanha',
#   'sao manoel do guaiacu',
#   'esao pauloera feliz',
#   'sao jose do mantimento',
#   'divino esao pauloirito santo',
#   'sao thome das letras',
#   'monsenhor paulo',
#   'sao bento abade',
#   'sao jose do alegre',
#   'esao pauloirito santo do dourado',
#   'sao joao da mata',
#   'sao pedro da uniao',
#   'sao tomas de aquino',
#   'sao joao batista do gloria',
#   'sao jose da barra',
#   'sao joao da serra negra',
#   'sao joao da chapada',
#   'sao joao do pacui',
#   'sao joao da lagoa',
#   'sao joao da ponte',
#   'sao joao das missoes',
#   'sao joao das missões',
#   'nova esao pauloeranca',
#   'esao pauloinosa',
#   'sao jose do jacuri',
#   'sao joao evangelista',
#   'sao pedro do suacui',
#   'sao jose da safira',
#   'frei gasao pauloar',
#   'sao jose do divino',
#   'sao miguel das matas',
#   'sao jose do jacuipe',
#   'morro de sao paulo',
#   'sao jose da vitoria',
#   'mata de sao joao',
#   'esao paulolanada',
#   'sao joao da fortaleza',
#   'sao miguel do aleixo',
#   'cedro de sao joao',
#   'sao bento do una',
#   'sao benedito do sul',
#   'sao jose da coroa grande',
#   'sao joaquim do monte',
#   'sao jose do egito',
#   'sao jose do belmonte',
#   'barra de sao miguel',
#   'sao miguel dos campos',
#   'sao jose da tapera',
#   'sao jose da laje',
#   'sao luis do quitunde',
#   'esao pauloeranca',
#   'sao miguel de taipu',
#   'cruz do esao pauloirito santo',
#   'sao jose dos ramos',
#   'sao jose da mata',
#   'sao jose dos cordeiros',
#   'sao joao do cariri',
#   'sao joao do tigre',
#   'sao jose do sabugi',
#   'sao jose do bonfim',
#   'sao jose de princesa',
#   'sao jose de esao pauloinharas',
#   'sao jose da lagoa tapada',
#   'sao jose do brejo do cruz',
#   'sao joao do rio do peixe',
#   'sao jose de mipibu',
#   'esao pauloirito santo',
#   'serra de sao bento',
#   'sao bento do trairi',
#   'sao jose do serido',
#   'sao joao do sabugi',
#   'sao paulo do potengi',
#   'sao miguel do gostoso',
#   'sao bento do norte',
#   'sao jose do torto',
#   'sao luis do curu',
#   'sao joao do jaguaribe',
#   'sao joao de deus',
#   'esao pauloerantina',
#   'sao joao da fronteira',
#   'sao jose do peixe',
#   'sao joao da varjota',
#   'sao raimundo nonato',
#   'sao jose de ribamar',
#   'sao joao batista',
#   'sao joao do caru',
#   'sao joao dos patos',
#   'sao joao do soter',
#   'esao pauloerantinopolis',
#   'sao raimundo do doca bezerra',
#   'sao jose dos basilios',
#   'sao raimundo das mangabeiras',
#   'sao pedro da agua branca',
#   'sao pedro dos crentes',
#   'nova esao pauloeranca do piria',
#   'sao joao de pirabas',
#   'sao joao da baliza',
#   'sao paulo de olivenca',
#   "sao joao d'alianca",
#   'sao joao dalianca',
#   'sao joao d alianca',
#   'sao joao da parauna',
#   'sao luis de montes belos',
#   'sao luiz do norte',
#   'rio cresao pauloo',
#   'esao pauloigao do oeste',
#   "sao felipe d'oeste",
#   'sao valerio da natividade',
#   'porto esao pauloeridiao',
#   'sao jose do rio claro',
#   'sao jose do xingu',
#   'novo sao joaquim',
#   'sao jose do povo',
#   'sao pedro da cipa',
#   'sao jose dos pinhais',
#   'sao joao do triunfo',
#   'sao jose da boa vista',
#   'esao pauloigao alto do iguacu',
#   'sao jorge doeste',
#   "sao jorge d'oeste",
#   'sao jorge do oeste',
#   'nova esao pauloeranca do sudoeste',
#   'boa esao pauloeranca do iguacu',
#   'pinhal de sao bento',
#   'sao jose do itavo',
#   'sao pedro do iguacu',
#   'sao jeronimo da serra',
#   'sao pedro do ivai',
#   'sao joao do ivai',
#   'sao jorge do ivai',
#   'sao manoel do parana',
#   'sao jorge do patrocinio',
#   'esao pauloeranca nova',
#   'sao joao do caiua',
#   'sao pedro do parana',
#   'porto sao jose',
#   'sao jose do ivai',
#   'sao joao do itaperiu',
#   'sao jose do cerrito',
#   'sao joao do sul',
#   'gasao pauloar',
#   'sao bento do sul',
#   'sao joao do oeste',
#   'sao bernardino',
#   'sao jose dos ausentes',
#   'sao jose do hortencio',
#   'sao jose do sul',
#   'sao pedro da serra',
#   'vesao pauloasiano correa',
#   'sao jose do norte',
#   'sao martinho da serra',
#   'sao joao do polesine',
#   'sao pedro do sul',
#   'nova esao pauloeranca do sul',
#   'sao paulo das missoes',
#   'sao paulo das missões',
#   'sao jose das missões',
#   'sao jose das missoes',
#   'sao valerio do sul',
#   'esao pauloeranca do sul',
#   'sao valentim do sul',
#   'sao jose do herval',
#   'esao pauloumoso',
#   'sao jose do ouro',
#   'sao joao da urtiga'],
#  'jundiai': ['jundiai', 'jundia', 'jundiai do sul'],
#  'taboao da serra': ['taboao da serra',
#   'santa cruz da conceicao',
#   'serra azul',
#   'santo antonio da alegria',
#   'california da barra (barra do pirai)',
#   'serra',
#   'pedras de maria da cruz',
#   'santa maria da boa vista',
#   'santa cruz da baixa verde',
#   'serra alta'],
#  'osasco': ['osasco'],
#  'carapicuiba': ['carapicuiba', 'picui', 'cuiaba'],
#  'barueri': ['barueri'],
#  'santana de parnaiba': ['santana de parnaiba',
#   'rio de janeiro, rio de janeiro, brasil',
#   'anta',
#   'santana do paraopeba',
#   'juiz de fora',
#   'pe de serra',
#   'santana',
#   'parnaiba',
#   'porto de moz',
#   'dez de maio',
#   'tres de maio'],
#  'pirapora do bom jesus': ['pirapora do bom jesus',
#   'barra do turvo',
#   'bom fim do bom jesus',
#   'capela do alto',
#   'pilar do sul',
#   'paraiba do sul',
#   'barra do pirai',
#   'morro do coco',
#   'laje do muriae',
#   'valao do barro',
#   'bom jardim',
#   'mimoso do sul',
#   'braco do rio',
#   'penha do capim',
#   'morro do ferro',
#   'morro do pilar',
#   'dores do turvo',
#   'pedra do anta',
#   'campo do meio',
#   'bom sucesso',
#   'bom repouso',
#   'estrela do sul',
#   'pirapora',
#   'rio do prado',
#   'menino jesus',
#   'varzea do poco',
#   'barra do choca',
#   'pirai do norte',
#   'barra do rocha',
#   'rio do meio',
#   'rio do antonio',
#   'rio do pires',
#   'gentio do ouro',
#   'sitio do mato',
#   'apora',
#   'tomar do geru',
#   'campo do brito',
#   'serra do vento',
#   'bom conselho',
#   'lagoa do ouro',
#   'lagoa do carro',
#   'coite do noia',
#   'brejo do cruz',
#   'bom jesus',
#   'tibau do sul',
#   'rio do fogo',
#   'serra do mel',
#   'lagoa do mato',
#   'lagoa do sitio',
#   'paco do lumiar',
#   'lago do junco',
#   'bom lugar',
#   'maraja do sena',
#   'barra do corda',
#   'oeiras do para',
#   'rondon do para',
#   'mae do rio',
#   'serra do navio',
#   'boca do acre',
#   'pires do rio',
#   'vale do anari',
#   'borda do campo',
#   'agudo do sul',
#   'pirai do sul',
#   'foz do jordao',
#   'bom jesus do sul',
#   'foz do iguacu',
#   'rio bom',
#   'pirapo',
#   'jandaia do sul',
#   'quinta do sol',
#   'cafezal do sul',
#   'itauna do sul',
#   'bom retiro',
#   'braco do norte',
#   'cocal do sul',
#   'timbe do sul',
#   'rio do sul',
#   'rio do campo',
#   'rio do oeste',
#   'jaragua do sul',
#   'ipora do oeste',
#   'formosa do sul',
#   'flor do sertao',
#   'campo bom',
#   'caxias do sul',
#   'cambara do sul',
#   'arroio do sal',
#   'rainha do mar',
#   'bom principio',
#   'arroio do meio',
#   'capao do leao',
#   'minas do leao',
#   'vale do sol',
#   'rosario do sul',
#   'capao do cipo',
#   'cristal do sul',
#   'bom progresso'],
#  'jandira': ['jandira', 'jandaira', 'jandaia', 'andira'],
#  'itapevi': ['itapevi', 'itapeva', 'itapebi', 'ita'],
#  'cotia': ['cotia'],
#  'vargem grande paulista': ['vargem grande paulista',
#   'praia grande',
#   'vargem',
#   'neves paulista',
#   'uniao paulista',
#   'tupi paulista',
#   'campo grande',
#   'ilha grande',
#   'vargem alegre',
#   'iguaba grande',
#   'vargem alta',
#   'paulista',
#   'casa grande',
#   'volta grande',
#   'vargem bonita',
#   'lagoa grande',
#   'paulistas',
#   'baixa grande',
#   'sitio grande',
#   'brejo grande',
#   'laje grande',
#   'cha grande',
#   'feira grande',
#   'mata grande',
#   'campina grande',
#   'serra grande',
#   'pedra grande',
#   'varzea grande',
#   'vargem grande',
#   'igarape grande',
#   'porto grande',
#   'morro grande',
#   'timbo grande',
#   'lajeado grande',
#   'arroio grande',
#   'pantano grande',
#   'pinhal grande',
#   'cerro grande',
#   'erval grande'],
#  'embu das artes': ['embu das artes',
#   'embu',
#   'santa cruz das palmeiras',
#   'divino das laranjeiras',
#   'santo antonio das queimadas',
#   "olho d'agua das flores",
#   'olho d agua das flores',
#   'boa vista das missoes'],
#  'itapecerica da serra': ['itapecerica da serra',
#   'serra negra',
#   'itapecerica',
#   'maria da fe',
#   'borda da mata',
#   'serra bonita',
#   'serra preta',
#   'itape',
#   'posto da mata',
#   'feira da mata',
#   'serra dourada',
#   'acu da torre',
#   'serra talhada',
#   'boca da mata',
#   'serra da raiz',
#   'serra redonda',
#   'serra branca',
#   'serra caiada',
#   'jose da penha',
#   'lago da pedra'],
#  'embu guacu': ['embu guacu', 'guacui', 'acu'],
#  'juquitiba': ['juquitiba', 'jequitiba', 'itiuba'],
#  'guarulhos': ['guarulhos'],
#  'adamantina': ['adamantina', 'diamantina'],
#  'aruja': ['aruja', 'guaruja', 'guaruja do sul'],
#  'santa isabel': ['santa isabel',
#   "santa barbara d'oeste",
#   'santa barbara d oeste',
#   'santa barbara doeste',
#   'santa barbara d`oeste',
#   'santa rita do passa quatro',
#   'santa rosa de viterbo',
#   "santa clara d'oeste",
#   "santa rita d'oeste",
#   'santa clara d oeste',
#   'santa rita d oeste',
#   'santa maria da serra',
#   'aguas de santa barbara',
#   'santa cruz do rio pardo',
#   'santa isabel do rio preto',
#   'santa rita da floresta',
#   'santa maria madalena',
#   'isabel',
#   'santa maria de jetiba',
#   'santa rita do itueto',
#   'central de santa helena',
#   'santa rita de minas',
#   'santa barbara do leste',
#   'santa cruz do escalvado',
#   'santa rita de ouro preto',
#   'santa terezinha de minas',
#   'santa rita do cedro',
#   'santa maria de itabira',
#   'santa rita de jacutinga',
#   'santa rita do ibitipoca',
#   'santa cruz de minas',
#   'cachoeira de santa cruz',
#   'santa rita do sapucai',
#   'santa rita de caldas',
#   'santa cruz do prata',
#   'santa rosa da serra',
#   'santa maria do suacui',
#   'santa helena de minas',
#   'santa cruz da vitoria',
#   'santa cruz cabralia',
#   'santa rita de cassia',
#   'santa maria da vitoria',
#   'santa luzia do itanhy',
#   'santa rosa de lima',
#   'santa cruz do capibaribe',
#   'santa maria do cambuca',
#   'santa luzia do norte',
#   'barra de santa rosa',
#   'santa cecilia de umbuzeiro',
#   'santa luzia do cariri',
#   'bonito de santa fe',
#   'santa luzia do parua',
#   'santa quiteria do maranhao',
#   'santa luzia do para',
#   'santa maria do para',
#   'santa isabel do para',
#   'santa cruz do arari',
#   'santa rosa do purus',
#   'santa cruz de goias',
#   'santa rosa de goias',
#   'santa rita do novo destino',
#   'santa tereza de goias',
#   "santa luzia d'oeste",
#   'santa luzia doeste',
#   'santa rita do trivelato',
#   'santa cruz do xingu',
#   'santa rita do pardo',
#   'santa maria do oeste',
#   'santa izabel do oeste',
#   'santa tereza do oeste',
#   'santa rita do oeste',
#   'santa isabel do ivai',
#   'santa cruz do timbo',
#   'santa maria do herval'],
#  'mairipora': ['mairipora', 'mairi', 'ipora'],
#  'cajamar': ['cajamar'],
#  'caieiras': ['caieiras', 'paineiras', 'capoeiras'],
#  'jordanesia': ['jordanesia', 'joanesia', 'jordania'],
#  'polvilho': ['polvilho'],
#  'maua': ['maua', 'visconde de maua', 'maua da serra', 'porto maua'],
#  'franco da rocha': ['franco da rocha'],
#  'francisco morato': ['francisco morato'],
#  'poa': ['poa',
#   'nipoa',
#   'marapoama',
#   'bom jesus do itabapoana',
#   'japoata',
#   'itapoa'],
#  'itaquaquecetuba': ['itaquaquecetuba', 'uba'],
#  'ferraz de vasconcelos': ['ferraz de vasconcelos',
#   'bento de abreu',
#   'torre de pedra',
#   'rio de janeiro',
#   'imbe de minas',
#   'para de minas',
#   'itau de minas',
#   'uniao de minas',
#   'irai de minas',
#   'patos de minas',
#   'fruta de leite',
#   'nelson de sena',
#   'dois de abril',
#   'rio de contas',
#   'belem de maria',
#   'pao de acucar',
#   'curral de cima',
#   'pedras de fogo',
#   'wall ferraz',
#   'brejo de areia',
#   'rolim de moura',
#   'porto de cima',
#   'treze de maio',
#   'terra de areia'],
#  'suzano': ['suzano'],
#  'mogi das cruzes': ['mogi das cruzes',
#   'mogidascruzes',
#   'mogi guacu',
#   'mogi mirim',
#   'cruzes',
#   'cruz'],
#  'salesopolis': ['salesopolis', 'sales', 'leopolis'],
#  'biritiba mirim': ['biritiba mirim'],
#  'guararema': ['guararema', 'guara', 'guarara'],
#  'santo andre': ['santo andre',
#   'santo antonio do pinhal',
#   'santo antonio de posse',
#   'santo antonio do jardim',
#   'santo antonio do aracangua',
#   'santo amaro de campos',
#   'santo antonio de padua',
#   'santo antonio do canaa',
#   'santo antonio do grama',
#   'santo antonio do manhuacu',
#   'santo antonio do leite',
#   'santo antonio do monte',
#   'santo antonio dos campos',
#   'santo antonio do norte',
#   'santo antonio do rio abaixo',
#   'santo antonio do aventureiro',
#   'monte santo de minas',
#   'santo antonio do itambe',
#   'santo antonio do retiro',
#   'santo antonio de jesus',
#   'vitoria de santo antao',
#   'barra de santo antonio',
#   'riacho de santo antonio'],
#  'ribeirao pires': ['ribeirao pires', 'ribeirao preto', 'ribeira', 'ribeirao'],
#  'rio grande da serra': ['rio grande da serra',
#   'rio claro',
#   'rio janeiro',
#   'rio bonito',
#   'rio acima',
#   'rio casca',
#   'rio doce',
#   'rio manso',
#   'rio pomba',
#   'rio melo',
#   'rio vermelho',
#   'rio real',
#   'rio largo',
#   'rio tinto',
#   'rio branco',
#   'rio bracnco',
#   'rio quente',
#   'rio verde',
#   'rio dos bois',
#   'rio sono',
#   'rio negro',
#   'rio azul',
#   'rio rufino',
#   'rio fortuna',
#   'rio negrinho',
#   'rio grande'],
#  'sbcampo': ['sbcampo'],
#  'diadema': ['diadema'],
#  'santos': ['santos',
#   'santos dumont',
#   'felicio dos santos',
#   'brejo dos santos',
#   'brejo santo',
#   'francisco santos',
#   'urbano santos'],
#  'bertioga': ['bertioga', 'ibertioga'],
#  'caruara': ['caruara', 'caruaru', 'carutapera', 'caraa'],
#  'sao vicente': ['sao vicente',
#   'sao vicente de paula',
#   'sao vicente do rio doce',
#   'sao vicente do grama',
#   'sao vicente da estrela',
#   'sao vicente de minas',
#   'sao vicente ferrer',
#   'sao vicente do sul'],
#  'cubatao': ['cubatao', 'ubata'],
#  'sao sebastiao': ['sao sebastiao',
#   'sao sebastiao da grama',
#   'sao sebastiao de campos',
#   'sao sebastiao do alto',
#   'sao sebastiao de braunas',
#   'sao sebastiao da barra',
#   'sao sebastiao da vala',
#   'sao sebastiao do anta',
#   'sao sebastiao do oeste',
#   'sao sebastiao do rio preto',
#   'sao sebastiao dos torres',
#   'sao sebastiao da vitoria',
#   'sao sebastiao da vargem alegre',
#   'sao sebastiao do sacramento',
#   'sao sebastiao do rio verde',
#   'sao sebastiao da bela vista',
#   'sao sebastiao do paraiso',
#   'sao sebastiao do pontal',
#   'sao sebastiao dos pocoes',
#   'sao sebastiao do maranhao',
#   'sao sebastiao do passe',
#   'sebastiao laranjeiras',
#   'sao joao',
#   'sao bras',
#   'sao sebastiao de lagoa de roca',
#   'sao tome',
#   'sao luis',
#   'sao sebastiao da boa vista',
#   'sao sebastiao do uatuma',
#   'sao luiz',
#   'sao sebastiao do tocantins',
#   'sao jose',
#   'sao sebastiao da amoreira',
#   'sao sebastiao do cai',
#   'sao sepe'],
#  'ubatuba': ['ubatuba', 'juatuba', 'umbauba'],
#  'ilhabela': ['ilhabela'],
#  'caraguatatuba': ['caraguatatuba'],
#  'maresias': ['maresias', 'areias'],
#  'mongagua': ['mongagua'],
#  'itanhaem': ['itanhaem', 'itanhem'],
#  'peruibe': ['peruibe', 'aperibe'],
#  'itariri': ['itariri'],
#  'pedro de toledo': ['pedro de toledo',
#   'sao pedro',
#   'cachoeiro de itapemirim',
#   'governador lacerda de aguiar',
#   'toledo',
#   'couto de magalhaes de minas',
#   'pai pedro',
#   'livramento de nossa senhora',
#   'pedro ii',
#   'nossa senhora de nazare',
#   'dom pedro',
#   'rio verde de mato grosso',
#   'nossa senhora de caravaggio'],
#  'ana dias': ['ana dias',
#   'antonio dias',
#   "dias d'avila",
#   'anadia',
#   'coronel jose dias'],
#  'miracatu': ['miracatu', 'catu'],
#  'juquia': ['juquia'],
#  'pariquera acu': ['pariquera acu', 'vau acu', 'tome acu'],
#  'cajati': ['cajati', 'jati', 'cajari'],
#  'registro': ['registro'],
#  'jacupiranga': ['jacupiranga', 'piranga', 'cupira', 'juripiranga'],
#  'ilha comprida': ['ilha comprida'],
#  'eldorado': ['eldorado', 'eldorado dos carajas', 'eldorado do sul'],
#  'iguape': ['iguape', 'guape'],
#  'cananeia': ['cananeia'],
#  'sete barras': ['sete barras',
#   'araras',
#   'barra',
#   'barras',
#   'tres barras do parana',
#   'tres barras'],
#  'taubate': ['taubate'],
#  'natividade da serra': ['natividade da serra', 'natividade'],
#  'tremembe': ['tremembe'],
#  'lagoinha': ['lagoinha',
#   'alagoinhas',
#   'alagoinha',
#   'lagoinha do piaui',
#   'alagoinha do piaui'],
#  'redencao da serra': ['redencao da serra', 'redencao'],
#  'catucaba': ['catucaba'],
#  'cacapava': ['cacapava', 'cacapava do sul'],
#  'paraibuna': ['paraibuna', 'ibiuna', 'dores do paraibuna', 'una', 'parauna'],
#  'jambeiro': ['jambeiro', 'rafael jambeiro'],
#  'monteiro lobato': ['monteiro lobato', 'monteiro', 'lobato'],
#  'jacarei': ['jacarei',
#   'jacare',
#   'conceicao de jacarei',
#   'santana do jacare',
#   'barra do jacare'],
#  'santa branca': ['santa branca',
#   'agua branca de minas',
#   'pedra branca do amapari'],
#  'igarata': ['igarata'],
#  'pindamonhangaba': ['pindamonhangaba'],
#  'campos do jordao': ['campos do jordao',
#   'vargem grande do soturno',
#   'venda nova do imigrante es',
#   'vargem grande do rio pardo',
#   'jordao',
#   'lagoa grande do maranhao',
#   'balneario arroio do silva'],
#  'guaratingueta': ['guaratingueta', 'guaratinga'],
#  'potim': ['potim'],
#  'aparecida': ['aparecida',
#   'aparecida d oeste',
#   "aparecida d'oeste",
#   'aparecida doeste',
#   'aparecida de monte alto',
#   'aparecida de sao manuel',
#   'nossa senhora da aparecida',
#   'conceicao da aparecida',
#   'aparecida de minas',
#   'nossa senhora aparecida',
#   'aparecida de goiania',
#   'aparecida do rio doce',
#   'aparecida do rio negro',
#   'aparecida do taboado',
#   'boa vista da aparecida'],
#  'cunha': ['cunha',
#   'campos de cunha',
#   'euclides da cunha paulista',
#   'porto velho do cunha',
#   'euclides da cunha',
#   'tracunhaem',
#   'afonso cunha',
#   "olho d'agua das cunhas",
#   'olho d agua das cunhas',
#   'olho dagua das cunhas',
#   'cunha pora',
#   'cunhatai',
#   'flores da cunha'],
#  'roseira': ['roseira', 'roseiral'],
#  'lorena': ['lorena'],
#  'cachoeira paulista': ['cachoeira paulista', 'cachoeira', 'cachoeira alta'],
#  'piquete': ['piquete'],
#  'silveiras': ['silveiras'],
#  'canas': ['canas', 'cangas', 'canoas'],
#  'cruzeiro': ['cruzeiro',
#   'cruzeiro da fortaleza',
#   'novo cruzeiro',
#   'cruzeiro do sul',
#   'cruzeiro do iguacu',
#   'cruzeiro do norte',
#   'cruzeiro do oeste'],
#  'lavrinhas': ['lavrinhas'],
#  'arapei': ['arapei'],
#  'queluz': ['queluz', 'luz', 'queluzito'],
#  'bananal': ['bananal', 'rio bananal'],
#  'atibaia': ['atibaia'],
#  'braganca paulista': ['braganca paulista', 'braganca', 'braga'],
#  'bom jesus dos perdoes': ['bom jesus dos perdoes',
#   'bom jesus dos perdões',
#   'angra dos reis',
#   'perdoes',
#   'rio dos indios'],
#  'piracaia': ['piracaia'],
#  'pedra bela': ['pedra bela',
#   'pedra do indaia',
#   'bela vista do maranhao',
#   'bela vista de goias',
#   'bela vista da caroba',
#   'bela vista do toldo',
#   'alto bela vista'],
#  'joanopolis': ['joanopolis',
#   'jardinopolis',
#   'josenopolis',
#   'rorainopolis',
#   'bonopolis',
#   'janiopolis'],
#  'nazare paulista': ['nazare paulista', 'palmares paulista', 'nazare'],
#  'pinhalzinho': ['pinhalzinho', 'pinhal'],
#  'tuiuti': ['tuiuti'],
#  'campinas': ['campinas',
#   'nova campina',
#   'campinal',
#   'campinas do piaui',
#   'campinacu',
#   'campinas do sul'],
#  'artur nogueira': ['artur nogueira', 'barao ataliba nogueira'],
#  'hortolandia': ['hortolandia',
#   'orlandia',
#   'ourolandia',
#   'hidrolandia',
#   'portelandia',
#   'nortelandia'],
#  'paulinia': ['paulinia', 'paulistania', 'pauliceia', 'pauini'],
#  'sumare': ['sumare'],
#  'cosmopolis': ['cosmopolis'],
#  'monte mor': ['monte mor',
#   'monte alegre do sul',
#   'monte azul paulista',
#   'monte aprazivel',
#   'monte verde paulista',
#   'campina do monte alegre'],
#  'engenheiro coelho': ['engenheiro coelho', 'coelho neto'],
#  'itatiba': ['itatiba',
#   'ibatiba',
#   'itagiba',
#   'itaiba',
#   'itatuba',
#   'itatiba do sul'],
#  'vinhedo': ['vinhedo', 'vale dos vinhedos'],
#  'valinhos': ['valinhos', 'galinhos'],
#  'varzea paulista': ['varzea paulista', 'varzea'],
#  'louveira': ['louveira'],
#  'jarinu': ['jarinu', 'jari'],
#  'campo limpo paulista': ['campo limpo paulista',
#   'abre campo',
#   'campo belo',
#   'campo florido',
#   'campo azul',
#   'belo campo',
#   'campo alegre',
#   'campo redondo',
#   'campo maior',
#   'campo verde',
#   'campo magro',
#   'campo largo',
#   'campo mourao',
#   'campo ere',
#   'campo novo'],
#  'morungaba': ['morungaba', 'mortugaba'],
#  'itupeva': ['itupeva', 'itu'],
#  'indaiatuba': ['indaiatuba'],
#  'capivari': ['capivari',
#   'santana do capivari',
#   'capivari de baixo',
#   'capivari do sul'],
#  'salto': ['salto',
#   'salto de pirapora',
#   'salto grande',
#   'salto da divisa',
#   'santa maria do salto',
#   'salto do ceu',
#   'salto do itarare',
#   'salto do lontra',
#   'rio do salto',
#   'salto veloso',
#   'salto do jacui'],
#  'nova odessa': ['nova odessa',
#   'nova canaa paulista',
#   'nova independencia',
#   'nova guataporanga',
#   'vila nova de campos',
#   'venda nova do imigrante',
#   'morada nova de minas',
#   'vila nova de minas',
#   'olinda nova do maranhao',
#   'feira nova do maranhao',
#   'vila nova dos martirios',
#   "nova brasilandia d'oeste",
#   'nova brasilandia doeste',
#   'nova brasilandia d oeste',
#   'nova bandeirantes',
#   'terra nova do norte',
#   'serra nova dourada',
#   'nova prata do iguacu'],
#  'cabreuva': ['cabreuva', 'jacare (cabreuva)'],
#  'elias fausto': ['elias fausto'],
#  'rafard': ['rafard'],
#  'rio das pedras': ['rio das pedras',
#   'visconde do rio branco',
#   'sao goncalo do rio das pedras',
#   'caicara do rio do vento'],
#  'mombuca': ['mombuca', 'mombaca'],
#  'cardeal': ['cardeal', 'areal', 'cardeal da silva', 'candeal'],
#  'americana': ['americana', 'nova america', 'americano'],
#  'limeira': ['limeira',
#   'limeira de mantena',
#   'rosario da limeira',
#   'limeira do oeste',
#   'limeira do oeste mg',
#   'limeira d oeste',
#   'nova palmeira'],
#  'piracicaba': ['piracicaba', 'rio piracicaba'],
#  'saltinho': ['saltinho', 'altinho'],
#  'cordeiropolis': ['cordeiropolis', 'cordeiro', 'cordeiros'],
#  'iracemapolis': ['iracemapolis'],
#  'sao carlos': ['sao carlos', 'sao carlos do ivai'],
#  'ipeuna': ['ipeuna', 'ipe'],
#  'santa gertrudes': ['santa gertrudes',
#   'santa ines',
#   'santa cruz',
#   'santa rosa',
#   'agua santa'],
#  'itirapina': ['itirapina', 'itirapua', 'ibiapina', 'itapiuna'],
#  'charqueada': ['charqueada', 'charqueadas'],
#  'ribeirao bonito': ['ribeirao bonito', 'bonito'],
#  'dourado': ['dourado',
#   'abadia dos dourados',
#   'douradoquara',
#   'joao dourado',
#   'gloria de dourados',
#   'dourados',
#   'serra dos dourados'],
#  'corumbatai': ['corumbatai', 'corumbatai do sul'],
#  'analandia': ['analandia',
#   'natalandia',
#   'acailandia',
#   'aloandia',
#   'anaurilandia'],
#  'santa eudoxia': ['santa eudoxia'],
#  'agua vermelha': ['agua vermelha',
#   "olhos d'agua do oeste",
#   'agua boa',
#   'aguas vermelhas',
#   "olho d'agua do casado",
#   "olho d'agua do borges",
#   'olho d agua do borges',
#   'agua doce do maranhao',
#   'lagoa vermelha'],
#  'pirassununga': ['pirassununga'],
#  'porto ferreira': ['porto ferreira',
#   'porto',
#   'porto rico do maranhao',
#   'porto alegre do norte',
#   'prado ferreira'],
#  'leme': ['leme', 'clementina', 'mateus leme', 'leme do prado'],
#  'descalvado': ['descalvado'],
#  'mococa': ['mococa'],
#  'casa branca': ['casa branca'],
#  'caconde': ['caconde'],
#  'tambau': ['tambau'],
#  'tapiratiba': ['tapiratiba', 'irati'],
#  'divinolandia': ['divinolandia', 'divino', 'divinolandia de minas'],
#  'itobi': ['itobi', 'itajobi', 'itaobim'],
#  'igarai': ['igarai'],
#  'lagoa branca': ['lagoa branca',
#   'aguia branca',
#   'agua branca',
#   'lagoa dos tres cantos'],
#  'venda branca': ['venda branca', 'pedra branca'],
#  'jaguariuna': ['jaguariuna', 'iuna', 'jaguaruana', 'juarina', 'jaguaruna'],
#  'vargem grande do sul': ['vargem grande do sul', 'lago sul', 'sul brasil'],
#  'holambra': ['holambra', 'holambra ii'],
#  'aguai': ['aguai',
#   'taguai',
#   'itaguai',
#   'araguaia',
#   'baguari',
#   'aguanil',
#   'conceicao do araguaia',
#   'brejo grande do araguaia',
#   'floresta do araguaia',
#   'santana do araguaia',
#   'sao geraldo do araguaia',
#   'sao domingos do araguaia',
#   'santa rita do araguaia',
#   'sao miguel do araguaia',
#   'formoso do araguaia',
#   'santa fe do araguaia',
#   'alto paraguai',
#   'araguaiana',
#   'bom jesus do araguaia',
#   'pontal do araguaia',
#   'sao felix do araguaia',
#   'araguainha',
#   'alto araguaia',
#   'miraguai'],
#  'conchal': ['conchal', 'conchas', 'cocal'],
#  'estiva gerbi': ['estiva gerbi', 'estiva'],
#  'aguas da prata': ['aguas da prata',
#   'santana da ponte pensa',
#   'lagoa da prata',
#   'costas da mantiqueira',
#   'prata',
#   'brejo da madre de deus',
#   'afogados da ingazeira',
#   'formosa da serra negra',
#   'aguas lindas de goias',
#   'chapada da natividade',
#   'vista alegre do prata'],
#  'martinho prado junior': ['martinho prado junior',
#   'rubiao junior',
#   'frei martinho',
#   'sao martinho',
#   'antonio prado'],
#  'amparo': ['amparo',
#   'amparo da serra',
#   'bom jesus do amparo',
#   'santo antonio do amparo',
#   'santo amaro',
#   'joao amaro',
#   'ribeira do amparo',
#   'amparo de sao francisco'],
#  'itapira': ['itapira',
#   'itapura',
#   'tapirai',
#   'itapirapua paulista',
#   'itabira',
#   'tapira',
#   'ipira',
#   'itamira',
#   'itapiratins',
#   'itapora'],
#  'socorro': ['socorro',
#   'perpetuo socorro',
#   'nossa senhora do socorro',
#   'socorro do piaui'],
#  'lindoia': ['lindoia', 'aguas de lindoia', 'lindoia do sul'],
#  'pedreira': ['pedreira',
#   'pederneiras',
#   'pereiras',
#   'miguel pereira',
#   'antonio pereira',
#   'simao pereira',
#   'vila pereira',
#   'pedreiras'],
#  'eleuterio': ['eleuterio'],
#  'sertaozinho': ['sertaozinho', 'sertao'],
#  'serrana': ['serrana', 'nova serrana', 'serrania', 'vista serrana'],
#  'pontal': ['pontal',
#   'pontalinda',
#   'rosario do pontal',
#   'pontalina',
#   'pontal do parana',
#   'pontao'],
#  'cravinhos': ['cravinhos'],
#  'bonfim paulista': ['bonfim paulista', 'bonfim'],
#  'guatapara': ['guatapara'],
#  'dumont': ['dumont', 'francisco dumont'],
#  'candia': ['candia', 'candeias', 'candiba', 'candoi', 'candiota'],
#  'cajuru': ['cajuru', 'uru', 'carmo do cajuru', 'cajuri', 'juru'],
#  'luis antonio': ['luis antonio',
#   'antonio prado de minas',
#   'luis eduardo magalhaes'],
#  'sao simao': ['sao simao', 'campina do simao'],
#  'cassia dos coqueiros': ['cassia dos coqueiros', 'cassia'],
#  'brodowski': ['brodowski'],
#  'batatais': ['batatais'],
#  'altinopolis': ['altinopolis',
#   'marinopolis',
#   'martinopolis',
#   'alvinopolis',
#   'alpinopolis',
#   'capinopolis',
#   'baianopolis',
#   'salinopolis',
#   'avelinopolis',
#   'alcinopolis'],
#  'franca': ['franca',
#   'engenheiro franca',
#   'passagem franca do piaui',
#   'passagem franca'],
#  'jeriquara': ['jeriquara', 'quadra', 'quarai'],
#  'rifaina': ['rifaina', 'faina'],
#  'cristais paulista': ['cristais paulista', 'cristais'],
#  'patrocinio paulista': ['patrocinio paulista', 'patrocinio'],
#  'pedregulho': ['pedregulho'],
#  'ribeirao corrente': ['ribeirao corrente', 'correntes', 'corrente'],
#  'restinga': ['restinga', 'agrestina', 'inga', 'restinga seca'],
#  'igarapava': ['igarapava'],
#  'ituverava': ['ituverava', 'itaverava', 'vera'],
#  'miguelopolis': ['miguelopolis'],
#  'aramina': ['aramina'],
#  'buritizal': ['buritizal', 'buri', 'buriti'],
#  'pioneiros': ['pioneiros', 'pinheiros'],
#  'ipua': ['ipua', 'ipuca', 'novo aripuana', 'aripuana', 'ipuacu'],
#  'morro agudo': ['morro agudo',
#   'agudo',
#   'morro cabeca no tempo',
#   'morro agudo de goias'],
#  'sales oliveira': ['sales oliveira',
#   'oliveira',
#   'oliveira dos brejinhos',
#   'capitao gervasio oliveira',
#   'doutor oliveira castro'],
#  'nuporanga': ['nuporanga', 'iporanga', 'ubaporanga'],
#  'juruce': ['juruce'],
#  'barretos': ['barretos', 'pereira barreto', 'tobias barreto'],
#  'bebedouro': ['bebedouro', 'ouro'],
#  'viradouro': ['viradouro', 'miradouro'],
#  'guaira': ['guaira',
#   'guaicara',
#   'guapiara',
#   'paranaiguara',
#   'chupinguaia',
#   'guaipora',
#   'guairaca'],
#  'colombia': ['colombia'],
#  'taiuva': ['taiuva'],
#  'pitangueiras': ['pitangueiras'],
#  'colina': ['colina',
#   'celina',
#   'colatina',
#   'coluna',
#   'colinas',
#   'nova colinas',
#   'carolina',
#   'colinas do sul',
#   'colinas do tocantins',
#   'nova america da colina'],
#  'severinia': ['severinia'],
#  'taiacu': ['taiacu', 'iacu'],
#  'terra roxa': ['terra roxa', 'laranja da terra'],
#  'ibitiuva': ['ibitiuva', 'imbituva'],
#  'jaborandi': ['jaborandi', 'jabora'],
#  'taquaral': ['taquaral',
#   'itaquara',
#   'taquarana',
#   'taquaral de goias',
#   'taquara'],
#  'araraquara': ['araraquara', 'arara'],
#  'gaviao peixoto': ['gaviao peixoto', 'gaviao'],
#  'jaboticabal': ['jaboticabal', 'jaboticatubas', 'jaboti', 'jaboticaba'],
#  'santa lucia': ['santa lucia',
#   'santa rita doeste',
#   'santa luzia',
#   'santa fe de minas',
#   'lucaia',
#   'santa fe de goias',
#   'santa rosa do sul',
#   'santa cruz do sul'],
#  'barrinha': ['barrinha', 'barroquinha'],
#  'ibate': ['ibate', 'ibateguara', 'caibate'],
#  'americo brasiliense': ['americo brasiliense', 'ico'],
#  'rincao': ['rincao', 'balneario rincao'],
#  'guariba': ['guariba',
#   'guaraciaba',
#   'guaiuba',
#   'jaguaribara',
#   'guaribas',
#   'guaiba'],
#  'pradopolis': ['pradopolis', 'pedranopolis', 'mirandopolis'],
#  'motuca': ['motuca'],
#  'ibitinga': ['ibitinga', 'iubatinga', 'biritinga', 'ibitiranga'],
#  'itapolis': ['itapolis', 'ritapolis', 'anitapolis', 'tunapolis'],
#  'novo horizonte': ['novo horizonte',
#   'novorizonte',
#   'novo lino',
#   'horizonte',
#   'centro novo do maranhao',
#   'novo gama',
#   'campo novo de rondonia',
#   'novo horizonte do oeste',
#   'novo horizonte do norte',
#   'novo horizonte do sul'],
#  'tabatinga': ['tabatinga', 'itatinga', 'batinga', 'taguatinga'],
#  'nova europa': ['nova europa'],
#  'irapua': ['irapua', 'deputado irapuan pinheiro', 'itapirapua'],
#  'borborema': ['borborema'],
#  'trabiju': ['trabiju'],
#  'tapinas': ['tapinas'],
#  'curupa': ['curupa', 'curua', 'gurupa', 'urupa', 'corupa'],
#  'mirassol': ['mirassol',
#   'mirassolandia',
#   "mirassol d'oeste",
#   'mirassol doeste',
#   'mirassol d oeste'],
#  'tanabi': ['tanabi'],
#  'jaci': ['jaci',
#   'jacigua',
#   'ijaci',
#   'jacui',
#   'santo antonio do jacinto',
#   'jacinto',
#   'avai do jacinto',
#   'paulo jacinto',
#   'jacilandia',
#   'jaci parana',
#   'jaciara',
#   'jacinto machado'],
#  'bady bassitt': ['bady bassitt'],
#  'sebastianopolis do sul': ['sebastianopolis do sul'],
#  'guapiacu': ['guapiacu'],
#  'nhandeara': ['nhandeara'],
#  'balsamo': ['balsamo'],
#  'potirendaba': ['potirendaba'],
#  'poloni': ['poloni'],
#  'ipigua': ['ipigua'],
#  'engenheiro balduino': ['engenheiro balduino'],
#  'jose bonifacio': ['jose bonifacio',
#   'poco de jose de moura',
#   'senador jose porfirio',
#   'sao bonifacio'],
#  'buritama': ['buritama', 'buritirama'],
#  'turiuba': ['turiuba'],
#  'macaubal': ['macaubal', 'macatuba', 'macaubas', 'macajuba', 'macau'],
#  'mendonca': ['mendonca'],
#  'adolfo': ['adolfo'],
#  'moncoes': ['moncoes', 'moncões'],
#  'planalto': ['planalto',
#   'planaltino',
#   'novo planalto',
#   'planalto da serra',
#   'planalto alegre',
#   'santo antonio do planalto'],
#  'zacarias': ['zacarias', 'acari'],
#  'ubarana': ['ubarana'],
#  'nova alianca': ['nova alianca',
#   'nova era',
#   'boa nova',
#   'alianca',
#   'nova alianca do ivai'],
#  'nova itapirema': ['nova itapirema',
#   'nova lima',
#   'nova ibia',
#   'casa nova',
#   'nova cruz',
#   'agua nova',
#   'nova roma',
#   'vila nova',
#   'sede nova'],
#  'lourdes': ['lourdes',
#   'campo alegre de lourdes',
#   'campo alegre de lourdes, bahia, brasil',
#   'nossa senhora de lourdes'],
#  'ilha solteira': ['ilha solteira'],
#  'general salgado': ['general salgado', 'salgado'],
#  'auriflama': ['auriflama'],
#  'magda': ['magda'],
#  'floreal': ['floreal', 'florestal'],
#  'gastao vidigal': ['gastao vidigal', 'vidigal'],
#  'nova luzitania': ['nova luzitania'],
#  'suzanapolis': ['suzanapolis'],
#  'sud mennucci': ['sud mennucci'],
#  'guzolandia': ['guzolandia'],
#  'nova castilho': ['nova castilho', 'castilho'],
#  "bandeirantes d'oeste": ["bandeirantes d'oeste",
#   "pingo d'agua",
#   'pingo d agua',
#   'bandeirantes',
#   'olhos d agua',
#   "olhos d'agua",
#   'bandeira',
#   "tanque d'arca",
#   "mae d'agua",
#   "olho d'agua",
#   "pau d'arco",
#   'pau d arco',
#   'rosario oeste',
#   'bandeirante'],
#  'olimpia': ['olimpia', 'nova olimpia'],
#  'riolandia': ['riolandia',
#   'purilandia',
#   'marilandia',
#   'retirolandia',
#   'agricolandia',
#   'simolandia',
#   'aurilandia',
#   'ivolandia',
#   'nova marilandia',
#   'cipolandia',
#   'ramilandia',
#   'rolandia',
#   'agrolandia',
#   'romelandia'],
#  'icem': ['icem', 'guiricema'],
#  'nova granada': ['nova granada', 'granada', 'nova ramada'],
#  'palestina': ['palestina',
#   'palestina do para',
#   'palestina de goias',
#   'palotina'],
#  'onda verde': ['onda verde', 'lucas do rio verde', 'nova casa verde'],
#  'guaraci': ['guaraci',
#   'guaracai',
#   'guaraciama',
#   'iguaraci',
#   'guaraciaba do norte',
#   'guarai'],
#  'orindiuva': ['orindiuva'],
#  'altair': ['altair', 'altamira'],
#  'cajobi': ['cajobi'],
#  'embauba': ['embauba'],
#  'baguacu': ['baguacu', 'biguacu'],
#  'valentim gentil': ['valentim gentil', 'gentil'],
#  'cardoso': ['cardoso',
#   'cardoso moreira',
#   'matias cardoso',
#   'antonio cardoso',
#   'erico cardoso',
#   'graccho cardoso',
#   'doutor mauricio cardoso'],
#  'votuporanga': ['votuporanga', 'poranga'],
#  'cosmorama': ['cosmorama'],
#  'pontes gestal': ['pontes gestal'],
#  'americo de campos': ['americo de campos', 'lima campos'],
#  'boa vista dos andradas': ['boa vista dos andradas',
#   'boa ventura',
#   'boa sorte',
#   'vista alegre',
#   'andradas',
#   'boa uniao',
#   'boa vista',
#   'boa viagem',
#   'boa hora',
#   'fonte boa',
#   'vila boa',
#   'alto boa vista',
#   'bela vista',
#   'terra boa',
#   'boa vista do cadeado',
#   'vista gaucha',
#   'nova boa vista'],
#  'mira estrela': ['mira estrela', 'estrela de jordania', 'estrela'],
#  'parisi': ['parisi'],
#  'alvares florence': ['alvares florence'],
#  'fernandopolis': ['fernandopolis', 'veranopolis'],
#  'ouroeste': ['ouroeste'],
#  'meridiano': ['meridiano'],
#  'indiapora': ['indiapora', 'indiara'],
#  "estrela d'oeste": ["estrela d'oeste",
#   'estrela d oeste',
#   'estrela doeste',
#   'estrela do norte',
#   'lambari d%26apos%3boeste',
#   "perola d'oeste"],
#  "guarani d'oeste": ["guarani d'oeste", 'guarani'],
#  'macedonia': ['macedonia'],
#  'populina': ['populina'],
#  'brasitania': ['brasitania', 'britania'],
#  'tres fronteiras': ['tres fronteiras',
#   'tres rios',
#   'passa tres',
#   'fronteira',
#   'fronteiras'],
#  'urania': ['urania', 'urucania', 'urandi', 'turvania', 'uruana'],
#  'jales': ['jales'],
#  'santa fe do sul': ['santa fe do sul',
#   'sacra familia do tingua',
#   'cabaceiras do paraguacu',
#   'campo alegre do fidalgo',
#   'baixa grande do ribeiro',
#   'ponte alta do bom jesus',
#   'santa fe'],
#  "palmeira d'oeste": ["palmeira d'oeste",
#   'palmeira doeste',
#   'palmeira d oeste'],
#  'vitoria brasil': ['vitoria brasil', 'vitoria'],
#  'santa albertina': ['santa albertina', 'albertina'],
#  'turmalina': ['turmalina'],
#  'santa salete': ['santa salete', 'salete'],
#  'rubineia': ['rubineia'],
#  'dirce reis': ['dirce reis'],
#  'sao francisco': ['sao francisco',
#   'sao francisco de itabapoana',
#   'barra de sao francisco',
#   'sao francisco de paula',
#   'sao francisco do gloria',
#   'sao francisco de sales',
#   'francisco sa',
#   'sao francisco do conde',
#   'muquem de sao francisco',
#   'muquem do sao francisco',
#   'caninde de sao francisco',
#   'santana do sao francisco',
#   'belem do sao francisco',
#   'belem de sao francisco',
#   'vila sao francisco',
#   'sao francisco do oeste',
#   'lagoa de sao francisco',
#   'sao francisco do piaui',
#   'sao francisco de assis do piaui',
#   'sao francisco do maranhao',
#   'sao francisco do brejao',
#   'sao francisco do para',
#   'sao francisco de goias',
#   'sao francisco do guapore',
#   'sao francisco do sul',
#   'sao francisco de assis'],
#  'dolcinopolis': ['dolcinopolis',
#   'lucianopolis',
#   'delfinopolis',
#   'neopolis',
#   'darcinopolis'],
#  'paranapua': ['paranapua',
#   'parapua',
#   'parana',
#   'parnagua',
#   'anapu',
#   'paranagua'],
#  'mesopolis': ['mesopolis'],
#  'pindorama': ['pindorama',
#   'panorama',
#   'pindoretama',
#   'pindorama do tocantins'],
#  'urupes': ['urupes'],
#  'catanduva': ['catanduva', 'catanduvas'],
#  'paraiso': ['paraiso',
#   'valparaiso',
#   'sao joao do paraiso',
#   'paraiso do tobias',
#   'santana do paraiso',
#   'paraisopolis',
#   'padre paraiso',
#   'valparaiso de goias',
#   'alto paraiso de goias',
#   'alto paraiso',
#   'vale do paraiso',
#   'paraiso do tocantins',
#   'paraiso das aguas',
#   'bela vista do paraiso',
#   'santo antonio do paraiso',
#   'paraiso do norte',
#   'paraiso do sul'],
#  'tabapua': ['tabapua'],
#  'catigua': ['catigua', 'caiua'],
#  'cedral': ['cedral'],
#  'novais': ['novais', 'rocas novas', 'lavras novas', 'caldas novas'],
#  'pirangi': ['pirangi', 'pirai'],
#  'uchoa': ['uchoa'],
#  'ibira': ['ibira',
#   'termas de ibira',
#   'ibirarema',
#   'ibiracu',
#   'ibiraci',
#   'ibia',
#   'ibiracatu',
#   'ibirataia',
#   'ibirapitanga',
#   'ibirapua',
#   'ibiraja',
#   'ibirajuba',
#   'ibiara',
#   'ibipora',
#   'ibiraiaras',
#   'ibiruba',
#   'ibirapuita'],
#  'elisiario': ['elisiario'],
#  'roberto': ['roberto', 'sao roberto'],
#  'ariranha': ['ariranha', 'barra do ariranha', 'ariranha do ivai'],
#  'matao': ['matao'],
#  'taquaritinga': ['taquaritinga',
#   'itinga',
#   'taquaritinga do norte',
#   'itaquitinga',
#   'taquari'],
#  'santa ernestina': ['santa ernestina', 'santa teresa', 'ernestina'],
#  'monte alto': ['monte alto',
#   'vista alegre do alto',
#   'alto mutum preto',
#   'barao de monte alto',
#   'palmas de monte alto',
#   'monte santo',
#   'alto do rodrigues',
#   'montes altos',
#   'monte carlo'],
#  'santa adelia': ['santa adelia',
#   'santa elvira',
#   'santa amelia',
#   'santa zelia',
#   'santa eliza'],
#  'botelho': ['botelho', 'botelhos', 'sao goncalo de botelhos'],
#  'fernando prestes': ['fernando prestes'],
#  'dobrada': ['dobrada'],
#  'candido rodrigues': ['candido rodrigues'],
#  'agulha': ['agulha'],
#  'jurupema': ['jurupema', 'jurema', 'urupema'],
#  'aracatuba': ['aracatuba', 'paracatu', 'aracatu', 'aratuba'],
#  'birigüi': ['birigüi', 'birigui'],
#  'piacatu': ['piacatu', 'piacatuba', 'icatu'],
#  'bilac': ['bilac'],
#  'gabriel monteiro': ['gabriel monteiro'],
#  'glicerio': ['glicerio'],
#  'brauna': ['brauna', 'braunas', 'barauna', 'ubauna'],
#  'coroados': ['coroados'],
#  'santopolis do aguapei': ['santopolis do aguapei'],
#  'brejo alegre': ['brejo alegre',
#   'alegre',
#   'campo alegre de minas',
#   'tabocas do brejo velho',
#   'campo alegre de goias',
#   'vista alegre do abuna',
#   'alta alegre dos parecis'],
#  'juritis': ['juritis', 'buritis'],
#  'penapolis': ['penapolis', 'eunapolis', 'arenapolis'],
#  'promissao': ['promissao'],
#  'luiziania': ['luiziania', 'luzilandia', 'luziania', 'luiziana'],
#  'avanhandava': ['avanhandava'],
#  'alto alegre': ['alto alegre',
#   'capela do alto alegre',
#   'alto alegre do pindare',
#   'alto alegre do maranhao',
#   'alto alegre dos parecis',
#   'alto alegre do iguacu'],
#  'barbosa': ['barbosa',
#   'matias barbosa',
#   'ruy barbosa',
#   'barbosa ferraz',
#   'carlos barbosa'],
#  'lins': ['lins'],
#  'sabino': ['sabino', 'sabinopolis'],
#  'getulina': ['getulina'],
#  'guaimbe': ['guaimbe', 'imbe'],
#  'cafelandia': ['cafelandia',
#   'cafe',
#   'chaveslandia',
#   'ceilandia',
#   'castelandia'],
#  'guaranta': ['guaranta', 'guaraita', 'guaranta do norte', 'guaratuba'],
#  'simoes': ['simoes', 'simões'],
#  'presidente alves': ['presidente alves',
#   'presidente tancredo neves',
#   'presidente janio quadros',
#   'presidente castelo branco',
#   'luiz alves',
#   'presidente castello branco'],
#  'pongai': ['pongai'],
#  'avai': ['avai', 'sao pedro do avai', 'indiavai', 'paranavai'],
#  'pirajui': ['pirajui', 'piraju'],
#  'balbinos': ['balbinos'],
#  'guararapes': ['guararapes',
#   'jaboatao dos guararapes',
#   'jaboatao dos gurarapes'],
#  'rubiacea': ['rubiacea'],
#  'lavinia': ['lavinia'],
#  'tres aliancas': ['tres aliancas'],
#  'andradina': ['andradina', 'nova andradina'],
#  'murutinga do sul': ['murutinga do sul', 'utinga'],
#  'bauru': ['bauru'],
#  'arealva': ['arealva'],
#  'iacanga': ['iacanga'],
#  'reginopolis': ['reginopolis',
#   'rinopolis',
#   'areiopolis',
#   'eugenopolis',
#   'virginopolis',
#   'arenopolis'],
#  'domelia': ['domelia'],
#  'jacuba': ['jacuba'],
#  'jau': ['jau',
#   'barao de grajau',
#   'grajau',
#   'itaipava do grajau',
#   'jaupaci',
#   'jau do tocantins',
#   'jauru'],
#  'itapui': ['itapui', 'icapui', 'apui', 'itaqui'],
#  'bariri': ['bariri'],
#  'itaju': ['itaju', 'itajuba', 'itajuipe', 'itaju do colonia'],
#  'boraceia': ['boraceia'],
#  'bocaina': ['bocaina', 'bocaina de minas', 'bocaina do sul'],
#  'santelmo': ['santelmo'],
#  'potunduva': ['potunduva'],
#  'guaianas': ['guaianas'],
#  'barra bonita': ['barra bonita',
#   'california da barra',
#   'barra do tarrachil',
#   'barra dos coqueiros',
#   'barra de guabiraba',
#   'balneario barra do sul'],
#  'brotas': ['brotas', 'brotas de macaubas', 'santo amaro das brotas'],
#  'igaracu do tiete': ['igaracu do tiete', 'tiete', 'aracu'],
#  'dois corregos': ['dois corregos', 'dois irmaos do buriti'],
#  'mineiros do tiete': ['mineiros do tiete', 'mineiros'],
#  'torrinha': ['torrinha'],
#  'guarapua': ['guarapua', 'guarapari', 'arapua', 'guarapuava'],
#  'lupercio': ['lupercio'],
#  'garca': ['garca',
#   'morro da garca',
#   'aragarcas',
#   'barra do garcas',
#   'alto garcas'],
#  'duartina': ['duartina'],
#  'galia': ['galia'],
#  'alvaro de carvalho': ['alvaro de carvalho', 'carvalhos'],
#  'piratininga': ['piratininga', 'piratini'],
#  'cabralia paulista': ['cabralia paulista',
#   'cuiaba paulista',
#   'maraba paulista'],
#  'ubirajara': ['ubirajara', 'ibiajara', 'ubajara'],
#  'alvinlandia': ['alvinlandia'],
#  'fernao': ['fernao'],
#  'jafa': ['jafa'],
#  'marilia': ['marilia', 'marilac', 'mari'],
#  'julio mesquita': ['julio mesquita', 'mesquita'],
#  'queiroz': ['queiroz'],
#  'pompeia': ['pompeia'],
#  'vera cruz': ['vera cruz',
#   'vera cruz de minas',
#   'cruz das almas',
#   'tenente laurentino cruz',
#   'riacho da cruz',
#   'vera cruz do oeste',
#   'porto vera cruz'],
#  'oriente': ['oriente',
#   'belo oriente',
#   'sao joao do oriente',
#   'novo oriente de minas',
#   'novo oriente',
#   'novo oriente do piaui'],
#  'ocaucu': ['ocaucu'],
#  'tupa': ['tupa',
#   'tupaciguara',
#   'tuparece',
#   'tupanatinga',
#   'tuparetama',
#   'matupa',
#   'tupassi',
#   'tupandi',
#   'tupancireta',
#   'tuparendi',
#   'tupanci do sul'],
#  'bastos': ['bastos'],
#  'herculandia': ['herculandia'],
#  'iacri': ['iacri'],
#  'quintana': ['quintana', 'quinta'],
#  'arco iris': ['arco iris'],
#  'osvaldo cruz': ['osvaldo cruz'],
#  'lucelia': ['lucelia'],
#  'sagres': ['sagres'],
#  'inubia paulista': ['inubia paulista', 'inubia'],
#  'pracinha': ['pracinha', 'pratinha', 'prainha'],
#  'salmourao': ['salmourao'],
#  'junqueiropolis': ['junqueiropolis', 'junqueiro'],
#  'pacaembu': ['pacaembu', 'caem'],
#  'flora rica': ['flora rica'],
#  'florida paulista': ['florida paulista', 'florida'],
#  'irapuru': ['irapuru', 'uirapuru'],
#  'mariapolis': ['mariapolis', 'marizopolis', 'mariopolis'],
#  'dracena': ['dracena'],
#  'ouro verde': ['ouro verde',
#   'corrego do ouro',
#   'ouro verde de minas',
#   'ouro verde de goias',
#   'ouro preto do oeste',
#   'ouro verde do piquiri',
#   'ouro verde do oeste'],
#  'monte castelo': ['monte castelo',
#   'castelo',
#   'monte carmelo',
#   'santa cruz de monte castelo'],
#  'santa mercedes': ['santa mercedes', 'mercedes'],
#  'jamaica': ['jamaica'],
#  'sorocaba': ['sorocaba'],
#  'mairinque': ['mairinque'],
#  'sao roque': ['sao roque',
#   'sao roque do canaa',
#   'sao roque do cannaa',
#   'sao roque de minas',
#   'sao roque do paraguacu',
#   'boa ventura de sao roque',
#   'sao roque do chopim',
#   'roque gonzales'],
#  'votorantim': ['votorantim'],
#  'aluminio': ['aluminio'],
#  'aracariguama': ['aracariguama'],
#  'aracoiaba da serra': ['aracoiaba da serra', 'aracoiaba'],
#  'piedade': ['piedade',
#   'piedade de caratinga',
#   'piedade de ponte nova',
#   'piedade dos gerais',
#   'piedade do paraopeba',
#   'piedade do rio grande',
#   'sao geraldo da piedade'],
#  'paruru': ['paruru', 'paracuru'],
#  'angatuba': ['angatuba', 'natuba', 'anajatuba'],
#  'alambari': ['alambari', 'lambari'],
#  'tatui': ['tatui'],
#  'itapetininga': ['itapetininga', 'itapetinga'],
#  'sarapui': ['sarapui'],
#  'cesario lange': ['cesario lange'],
#  'porangaba': ['porangaba'],
#  'guarei': ['guarei', 'mandaguari'],
#  'conceicao': ['conceicao',
#   'conceicao de macabu',
#   'conceicao do castelo',
#   'conceicao da barra',
#   'conceicao do capim',
#   'conceicao do para',
#   'conceicao do mato dentro',
#   'conceicao da ibitipoca',
#   'conceicao da barra de minas',
#   'conceicao de ipanema',
#   'conceicao do rio verde',
#   'conceicao dos ouros',
#   'conceicao das pedras',
#   'conceicao das alagoas',
#   'conceicao de tronqueiras',
#   'conceicao do jacuipe',
#   'conceicao da feira',
#   'conceicao do almeida',
#   'conceicao do coite',
#   'conceicao do caninde',
#   'conceicao do lago acu',
#   'conceicao do tocantins',
#   'rio da conceicao'],
#  'rechan': ['rechan'],
#  'gramadinho': ['gramadinho', 'gramado'],
#  'apiai': ['apiai'],
#  'capao bonito': ['capao bonito', 'rio bonito do iguacu', 'campo bonito'],
#  'itaoca': ['itaoca', 'itaocara'],
#  'ribeirao grande': ['ribeirao grande'],
#  'barra do chapeu': ['barra do chapeu', 'apeu'],
#  'itarare': ['itarare',
#   'bom sucesso de itarare',
#   'itacare',
#   'santana do itarare'],
#  'itabera': ['itabera',
#   'itubera',
#   'itabela',
#   'itaberaba',
#   'itaberai',
#   'nova itaberaba'],
#  'itaporanga': ['itaporanga',
#   'caporanga',
#   'itarana',
#   'iraporanga',
#   "itaporanga d'ajuda",
#   'ipaporanga',
#   'itapiranga',
#   'itapuranga',
#   'ituporanga'],
#  'taquarivai': ['taquarivai', 'itaquarai', 'ivai'],
#  'riversul': ['riversul', 'rive'],
#  'guarizinho': ['guarizinho'],
#  'ribeirao branco': ['ribeirao branco'],
#  'barao de antonina': ['barao de antonina', 'antonina', 'barao'],
#  'boituva': ['boituva'],
#  'cerquilho': ['cerquilho'],
#  'porto feliz': ['porto feliz', 'porto dos gauchos', 'feliz'],
#  'ipero': ['ipero'],
#  'laranjal paulista': ['laranjal paulista', 'laranjal'],
#  'jumirim': ['jumirim', 'umirim'],
#  'bofete': ['bofete'],
#  'maristela': ['maristela'],
#  'lencois paulista': ['lencois paulista', 'lencois'],
#  'sao manuel': ['sao manuel'],
#  'botucatu': ['botucatu'],
#  'borebi': ['borebi'],
#  'anhembi': ['anhembi'],
#  'pardinho': ['pardinho', 'parazinho'],
#  'alfredo guedes': ['alfredo guedes'],
#  'pratania': ['pratania'],
#  'piramboia': ['piramboia'],
#  'avare': ['avare', 'tavares'],
#  'cerqueira cesar': ['cerqueira cesar'],
#  'taquarituba': ['taquarituba', 'itauba'],
#  'paranapanema': ['paranapanema',
#   'mirante do paranapanema',
#   'paranatama',
#   'paranapoema'],
#  'coronel macedo': ['coronel macedo',
#   'coronel pacheco',
#   'coronel xavier chaves',
#   'coronel domingos soares'],
#  'itai': ['itai',
#   'itaipava',
#   'itaimbe',
#   'itaim',
#   'jequitai',
#   'itaipe',
#   'itagi',
#   'itaitinga',
#   'itaicaba',
# ...
#  'alto calcado': ['alto calcado', 'calcado'],
#  'jeronimo monteiro': ['jeronimo monteiro'],
#  'dores do rio preto': ['dores do rio preto',
#   'ouro preto',
#   'rio preto',
#   'barro preto'],
#  'ibitirama': ['ibitirama', 'ibitira', 'ibitiara', 'ibotirama', 'ibirama'],
#  'afonso claudio': ['afonso claudio', 'claudio'],
#  'santa leopoldina': ['santa leopoldina', 'leopoldina'],
#  'joao neiva': ['joao neiva', 'coronel joao sa'],
#  'itaguacu': ['itaguacu',
#   'ituacu',
#   'itaguacu da bahia',
#   'ipanguacu',
#   'itaucu',
#   'itaguaru'],
#  'brejetuba': ['brejetuba'],
#  'acioli': ['acioli'],
#  'baixo guandu': ['baixo guandu'],
#  'pancas': ['pancas', 'placas'],
#  'vila valerio': ['vila valerio'],
#  'mantenopolis': ['mantenopolis',
#   'santa luzia de mantenopolis',
#   'santanopolis'],
#  'vila verde': ['vila verde'],
#  'alto rio novo': ['alto rio novo', 'formosa do rio preto'],
#  'governador lindenberg': ['governador lindenberg'],
#  'lajinha': ['lajinha'],
#  'novo brasil': ['novo brasil',
#   'brasil novo',
#   'novo repartimento',
#   'americano do brasil'],
#  'quilometro 14 do mutum': ['quilometro 14 do mutum', 'mutum', 'mutum parana'],
#  'ecoporanga': ['ecoporanga'],
#  'nova venecia': ['nova venecia', 'nova veneza'],
#  'montanha': ['montanha', 'montanhas'],
#  'mucurici': ['mucurici', 'murici'],
#  'vila pavao': ['vila pavao', 'pavao'],
#  'agua doce do norte': ['agua doce do norte',
#   'agua fria',
#   'agua preta',
#   'agua limpa',
#   'agua clara',
#   'mirim doce',
#   'agua doce'],
#  'vila nelita': ['vila nelita'],
#  'itabaiana': ['itabaiana', 'itabatan', 'itabaianinha', 'tabai'],
#  'ponto belo': ['ponto belo',
#   'ponto dos volantes',
#   'ponto do marambaia',
#   'porto belo',
#   'campo belo do sul'],
#  'santo agostinho': ['santo agostinho', 'cabo de santo agostinho'],
#  'monte sinai': ['monte sinai', 'monte siao'],
#  'vinhatico': ['vinhatico'],
#  'linhares': ['linhares', 'linharesl'],
#  'sao mateus': ['sao mateus',
#   'sao mateus de minas',
#   'sao mateus do maranhao',
#   'sao mateus do sul'],
#  'sooretama': ['sooretama'],
#  'jaguare': ['jaguare', 'jaguaripe', 'jaguaribe', 'jaguaretama'],
#  'pedro canario': ['pedro canario'],
#  'cristal do norte': ['cristal do norte', 'cristal'],
#  'itaunas': ['itaunas', 'itauna', 'jitauna', 'itabuna', 'itau', 'tunas'],
#  'belo horizonte': ['belo horizonte',
#   'belo horizonta',
#   'belo vale',
#   'alto horizonte'],
#  'bh': ['bh'],
#  'contagem': ['contagem'],
#  'sarzedo': ['sarzedo', 'varzedo'],
#  'ibirite': ['ibirite'],
#  'betim': ['betim'],
#  'lagoa santa': ['lagoa santa', "lagoa d'anta", 'lagoa da confusao'],
#  'confins': ['confins'],
#  'pedro leopoldo': ['pedro leopoldo'],
#  'ribeirao das neves': ['ribeirao das neves'],
#  'taquaracu de minas': ['taquaracu de minas', 'minas novas'],
#  'sabara': ['sabara', 'saubara', 'abaira', 'seabra'],
#  'ravena': ['ravena'],
#  'caete': ['caete', 'caetite', 'caetes'],
#  'morro vermelho': ['morro vermelho', 'vermelho', 'mar vermelho'],
#  'governador valadares': ['governador valadares'],
#  'timoteo': ['timoteo'],
#  'coronel fabriciano': ['coronel fabriciano', 'coronel bicaco'],
#  'ipatinga': ['ipatinga'],
#  'itanhomi': ['itanhomi'],
#  'pescador': ['pescador'],
#  'nova modica': ['nova modica'],
#  'frei inocencio': ['frei inocencio'],
#  'alpercata': ['alpercata'],
#  'tarumirim': ['tarumirim', 'itumirim'],
#  'engenheiro caldas': ['engenheiro caldas', 'caldas'],
#  'marlieria': ['marlieria'],
#  'iapu': ['iapu'],
#  'dom cavati': ['dom cavati', 'dom macedo costa', 'dom expedito lopes'],
#  'acucena': ['acucena'],
#  'mathias lobato': ['mathias lobato'],
#  'naque': ['naque', 'naque nanuque', 'nanuque', 'nioaque'],
#  'periquito': ['periquito'],
#  'tumiritinga': ['tumiritinga'],
#  'sobralia': ['sobralia', 'sobral'],
#  'bugre': ['bugre', 'barra do bugres', 'lajeado do bugre'],
#  'jaguaracu': ['jaguaracu', 'iguaracu', 'jaguarao'],
#  'goiabal': ['goiabal', 'sao jose do goiabal'],
#  'chonim': ['chonim'],
#  'mantena': ['mantena', 'itabirinha de mantena'],
#  'itueta': ['itueta'],
#  'aimores': ['aimores', 'serra dos aimores'],
#  'conselheiro pena': ['conselheiro pena'],
#  'itabirinha': ['itabirinha', 'boa uniao de itabirinha'],
#  'goiabeira': ['goiabeira'],
#  'central de minas': ['central de minas', 'central'],
#  'cuparaque': ['cuparaque'],
#  'galileia': ['galileia'],
#  'alvarenga': ['alvarenga'],
#  'quatituba': ['quatituba', 'quatigua'],
#  'ferruginha': ['ferruginha'],
#  'barra do cuiete': ['barra do cuiete', 'barra do jacuipe'],
#  'calixto': ['calixto'],
#  'independencia': ['independencia'],
#  'aldeia': ['aldeia', 'aldeias altas'],
#  'matipo': ['matipo'],
#  'caratinga': ['caratinga',
#   'santa luzia de caratinga',
#   'igaratinga',
#   'catingal'],
#  'inhapim': ['inhapim', 'inhapi'],
#  'raul soares': ['raul soares'],
#  'sericita': ['sericita'],
#  'entre folhas': ['entre folhas',
#   'entre rios de minas',
#   'desterro de entre rios'],
#  'bom jesus do galho': ['bom jesus do galho'],
#  'pedra bonita': ['pedra bonita'],
#  'jequeri': ['jequeri', 'pequeri'],
#  'aguas ferreas': ['aguas ferreas', 'aguas frias'],
#  'padre fialho': ['padre fialho'],
#  'corrego novo': ['corrego novo', 'corrego do bom jesus'],
#  'vermelho novo': ['vermelho novo', 'vermelho velho'],
#  'bicuiba': ['bicuiba'],
#  'santa efigenia': ['santa efigenia', 'santa efigenia de minas'],
#  'santana do tabuleiro': ['santana do tabuleiro', 'tabuleiro'],
#  'grota': ['grota'],
#  'moeda': ['moeda'],
#  'mariana': ['mariana',
#   'passagem de mariana',
#   'santa mariana',
#   'mariana pimentel'],
#  'itabirito': ['itabirito'],
#  'brumadinho': ['brumadinho'],
#  'amarantina': ['amarantina', 'arantina', 'amaralina'],
#  'cachoeira do campo': ['cachoeira do campo', 'cachoeira do sul'],
#  'itaguara': ['itaguara', 'itaguari', 'itaara'],
#  'barra longa': ['barra longa'],
#  'oratorios': ['oratorios'],
#  'cachoeira do brumado': ['cachoeira do brumado',
#   'cachoeira dourada',
#   'brumado'],
#  'acaiaca': ['acaiaca'],
#  'dom silverio': ['dom silverio'],
#  'crucilandia': ['crucilandia'],
#  'sem peixe': ['sem peixe', 'peixe'],
#  'santa rita durao': ['santa rita durao', 'santa rita'],
#  'jeceaba': ['jeceaba'],
#  'monsenhor horta': ['monsenhor horta'],
#  'claudio manuel': ['claudio manuel'],
#  'diogo de vasconcelos': ['diogo de vasconcelos'],
#  'furquim': ['furquim'],
#  'rodrigo silva': ['rodrigo silva'],
#  'divinopolis': ['divinopolis',
#   'divisopolis',
#   'davinopolis',
#   'divinopolis de goias',
#   'vianopolis',
#   'divinopolis do tocantins'],
#  'formiga': ['formiga'],
#  'arcos': ['arcos',
#   'padre marcos',
#   'marcos parente',
#   'sao jose dos quatro marcos',
#   'sao marcos'],
#  'lamounier': ['lamounier'],
#  'perdigao': ['perdigao'],
#  'pimenta': ['pimenta', 'pimenta bueno'],
#  'pains': ['pains'],
#  'camacho': ['camacho'],
#  'esteios': ['esteios', 'esteio'],
#  'neolandia': ['neolandia', 'teolandia', 'mineirolandia'],
#  'passa tempo': ['passa tempo'],
#  'japaraiba': ['japaraiba', 'japaratuba'],
#  'boa vista de minas': ['boa vista de minas',
#   'bela vista de minas',
#   'boa vista do incra'],
#  'martins guimaraes': ['martins guimaraes', 'guimaraes'],
#  'pequi': ['pequi', 'pequizeiro'],
#  'abaete': ['abaete', 'cedro do abaete', 'abaetetuba'],
#  'maravilhas': ['maravilhas', 'maravilha'],
#  'martinho campos': ['martinho campos'],
#  'papagaios': ['papagaios'],
#  'moema': ['moema'],
#  'estrela do indaia': ['estrela do indaia', 'indaial'],
#  'pitangui': ['pitangui', 'onca de pitangui'],
#  'araujos': ['araujos'],
#  'pompeu': ['pompeu', 'senador pompeu'],
#  'itatiaiucu': ['itatiaiucu'],
#  'azurita': ['azurita'],
#  'quartel geral': ['quartel geral'],
#  'dores do indaia': ['dores do indaia'],
#  'leandro ferreira': ['leandro ferreira'],
#  'biquinhas': ['biquinhas'],
#  'engenho do ribeiro': ['engenho do ribeiro'],
#  'serra da saudade': ['serra da saudade', 'saudades'],
#  'alberto isaacson': ['alberto isaacson'],
#  'pocoes de paineiras': ['pocoes de paineiras', 'pocoes'],
#  'antunes': ['antunes', 'antunes (igaratinga)'],
#  'torneiros': ['torneiros'],
#  'sete lagoas': ['sete lagoas', 'tres lagoas'],
#  'paraopeba': ['paraopeba'],
#  'matozinhos': ['matozinhos', 'matinhos'],
#  'curvelo': ['curvelo'],
#  'capim branco': ['capim branco', 'capim', 'rio branco do ivai'],
#  'prudente de morais': ['prudente de morais'],
#  'esmeraldas': ['esmeraldas', 'esmeraldas de ferros', 'esmeralda'],
#  'baldim': ['baldim', 'anita garibaldi', 'garibaldi'],
#  'santana de pirapama': ['santana de pirapama'],
#  'funilandia': ['funilandia'],
#  'caetanopolis': ['caetanopolis', 'sertanopolis'],
#  'felixlandia': ['felixlandia'],
#  'inhauma': ['inhauma', 'inhuma'],
#  'fortuna de minas': ['fortuna de minas',
#   'fortaleza de minas',
#   'uruana de minas',
#   'fortuna'],
#  'cachoeira da prata': ['cachoeira da prata',
#   'cachoeira do piria',
#   'cachoeira de piria'],
#  'cordisburgo': ['cordisburgo'],
#  'mocambeiro': ['mocambeiro', 'cambe'],
#  'anguereta': ['anguereta', 'anguera'],
#  'inimutaba': ['inimutaba'],
#  'carmesia': ['carmesia'],
#  'congonhas do norte': ['congonhas do norte', 'congonhas', 'congo'],
#  'ferros': ['ferros', 'pau dos ferros'],
#  'dom joaquim': ['dom joaquim', 'sao joaquim'],
#  'santana do riacho': ['santana do riacho',
#   'riacho de santana',
#   'riacho frio',
#   'santana do maranhao'],
#  'itambe do mato dentro': ['itambe do mato dentro',
#   'mato verde',
#   'itambe',
#   'mato grosso',
#   'mato rico',
#   'mato leitao',
#   'mato queimado'],
#  'dores de guanhaes': ['dores de guanhaes', 'guanhaes'],
#  'passabem': ['passabem'],
#  'gororos': ['gororos', 'oros'],
#  'joao monlevade': ['joao monlevade', 'joao dias'],
#  'barao de cocais': ['barao de cocais', 'cocais'],
#  'santa barbara': ['santa barbara',
#   'santa barbara do monte verde',
#   'santa barbara do tugurio',
#   'santa barbara do para',
#   'santa barbara de goias',
#   'nova santa barbara',
#   'santa barbara do sul'],
#  'catas altas': ['catas altas', 'catas altas da noruega'],
#  'dionisio': ['dionisio', 'dionisio cerqueira'],
#  'ipoema': ['ipoema'],
#  'fonseca': ['fonseca'],
#  'barra feliz': ['barra feliz'],
#  'lima duarte': ['lima duarte'],
#  'ewbank da camara': ['ewbank da camara', 'cambara'],
#  'belmiro braga': ['belmiro braga'],
#  'goiana': ['goiana', 'goiania', 'goianapolis', 'goianira'],
#  'pirauba': ['pirauba', 'pirajuba', 'irajuba', 'piratuba'],
#  'chacara': ['chacara', 'caicara'],
#  'paiva': ['paiva'],
#  'merces': ['merces', 'merces de agua limpa'],
#  'silveirania': ['silveirania', 'silvania', 'irani'],
#  'piau': ['piau',
#   'cabeceiras do piaui',
#   'morro do chapeu do piaui',
#   'bom principio do piaui',
#   'caraubas do piaui',
#   'boqueirao do piaui',
#   'juazeiro do piaui',
#   'castelo do piaui',
#   'sao felix do piaui',
#   'assuncao do piaui',
#   'prata do piaui',
#   'lagoa do piaui',
#   'sao pedro do piaui',
#   'angical do piaui',
#   "olho d'agua do piaui",
#   'caridade do piaui',
#   'ipiranga do piaui',
#   'campo grande do piaui',
#   'santo inacio do piaui',
#   'santa cruz do piaui',
#   'floresta do piaui',
#   'santa rosa do piaui',
#   'tanque do piaui',
#   'cajazeiras do piaui',
#   'curral novo do piaui',
#   'massape do piaui',
#   'vila nova do piaui',
#   'alegrete do piaui',
#   'sao jose do piaui',
#   'caldeirao grande do piaui',
#   'santana do piaui',
#   'belem do piaui',
#   'sao joao do piaui',
#   'bela vista do piaui',
#   'ribeira do piaui',
#   'sao braz do piaui',
#   'lagoa do barro do piaui',
#   'sao lourenco do piaui',
#   'betania do piaui',
#   'jacobina do piaui',
#   'tamboril do piaui',
#   'rio grande do piaui',
#   'brejo do piaui',
#   'flores do piaui',
#   'porto alegre do piaui',
#   'pajeu do piaui',
#   'nazare do piaui',
#   'palmeira do piaui',
#   'barreiras do piaui',
#   'cristalandia do piaui'],
#  'santana do garambeu': ['santana do garambeu', 'santana do acarau'],
#  'sarandira': ['sarandira'],
#  'olaria': ['olaria'],
#  'rosario de minas': ['rosario de minas', 'rio pardo de minas', 'rosario'],
#  'pedro teixeira': ['pedro teixeira',
#   'teixeiras',
#   'teixeira',
#   'governador jorge teixeira'],
#  'barbacena': ['barbacena'],
#  'aracitaba': ['aracitaba', 'araci'],
#  'dores de campos': ['dores de campos'],
#  'carandai': ['carandai', 'caranaiba'],
#  'cipotanea': ['cipotanea', 'cipo'],
#  'barroso': ['barroso',
#   'governador eugenio barros',
#   'adhemar de barros',
#   'coronel barros'],
#  'alto rio doce': ['alto rio doce', 'vitorinos alto rio doce'],
#  'senhora dos remedios': ['senhora dos remedios',
#   'nossa senhora dos remedios'],
#  'correia de almeida': ['correia de almeida', 'luis correia'],
#  'capela nova': ['capela nova', 'capela', 'capela de santana'],
#  'antonio carlos': ['antonio carlos'],
#  'senhora das dores': ['senhora das dores', 'nossa senhora das dores'],
#  'alfredo vasconcelos': ['alfredo vasconcelos', 'joao alfredo'],
#  'desterro do melo': ['desterro do melo', 'desterro'],
#  'bias fortes': ['bias fortes'],
#  'ressaquinha': ['ressaquinha'],
#  'pinheiro grosso': ['pinheiro grosso', 'grossos', 'pinheiro'],
#  'oliveira fortes': ['oliveira fortes'],
#  'vitorinos': ['vitorinos', 'manoel vitorino', 'vitorino'],
#  'lagoa dourada': ['lagoa dourada'],
#  'tiradentes': ['tiradentes', 'novo tiradentes', 'tiradentes do sul'],
#  'sao tiago': ['sao tiago'],
#  'itutinga': ['itutinga'],
#  'nazareno': ['nazareno', 'nazarezinho'],
#  'prados': ['prados', 'prado'],
#  'conselheiro lafaiete': ['conselheiro lafaiete'],
#  'ouro branco': ['ouro branco', 'poco branco', 'rio branco do sul'],
#  'lamim': ['lamim'],
#  'senhora de oliveira': ['senhora de oliveira'],
#  'cristiano otoni': ['cristiano otoni'],
#  'santana dos montes': ['santana dos montes',
#   'santana dos garrotes',
#   'montese'],
#  'alto maranhao': ['alto maranhao', 'altamira do maranhao', 'alto parana'],
#  'pinheiros altos': ['pinheiros altos', 'altos'],
#  'vicosa': ['vicosa', 'nova vicosa', 'vicosa do ceara'],
#  'ervalia': ['ervalia'],
#  'coimbra': ['coimbra'],
#  'sao geraldo': ['sao geraldo', 'sao geraldo do baguari'],
#  'porto firme': ['porto firme'],
#  'tocantins': ['tocantins',
#   'bom jesus do tocantins',
#   'tonantins',
#   'aurora do tocantins',
#   'porto alegre do tocantins',
#   'sao salvador do tocantins',
#   'santa rosa do tocantins',
#   'taipas do tocantins',
#   'cariri do tocantins',
#   'alianca do tocantins',
#   'crixas do tocantins',
#   'ponte alta do tocantins',
#   'dois irmaos do tocantins',
#   'marianopolis do tocantins',
#   'monte santo do tocantins',
#   'tocantinia',
#   'lagoa do tocantins',
#   'santa tereza do tocantins',
#   'itapora do tocantins',
#   'bandeirantes do tocantins',
#   'santa maria do tocantins',
#   'brasilandia do tocantins',
#   'santa terezinha do tocantins',
#   'buriti do tocantins',
#   'sitio novo do tocantins',
#   'palmeiras do tocantins',
#   'sao miguel do tocantins',
#   'maurilandia do tocantins',
#   'sao bento do tocantins',
#   'axixa do tocantins'],
#  'guidoval': ['guidoval'],
#  'divinesia': ['divinesia'],
#  'senador firmino': ['senador firmino', 'senador sa'],
#  'rodeiro': ['rodeiro', 'roteiro', 'rodeio'],
#  'araponga': ['araponga', 'arapongas'],
#  'paula candido': ['paula candido'],
#  'bras pires': ['bras pires', 'luiz pires de minas'],
#  'canaa': ['canaa', 'nova canaa', 'canaa dos carajas', 'nova canaa do norte'],
#  'descoberto': ['descoberto', 'santo antonio do descoberto'],
#  'alem paraiba': ['alem paraiba'],
#  'sao domingos': ['sao domingos',
#   'ribeirao de sao domingos',
#   'sao domingos do cariri',
#   'sao domingos do maranhao',
#   'sao domingos do azeitao',
#   'sao domingos do capim',
#   'vale de sao domingos',
#   'sao domingos do sul'],
#  'bicas': ['bicas'],
#  'angustura': ['angustura'],
#  'rochedo de minas': ['rochedo de minas', 'rochedo'],
#  'maripa de minas': ['maripa de minas', 'maripa'],
#  'senador cortes': ['senador cortes', 'cortes', 'senador eloi de souza'],
#  'santana do deserto': ['santana do deserto', 'santana do serido', 'deserto'],
#  'chiador': ['chiador'],
#  'mirai': ['mirai', 'miraima'],
#  'cataguases': ['cataguases', 'santana de cataguases'],
#  'recreio': ['recreio'],
#  'cataguarino': ['cataguarino'],
#  'astolfo dutra': ['astolfo dutra'],
#  'palma': ['palma',
#   'varzea da palma',
#   'palmares',
#   'uniao dos palmares',
#   'palmacia',
#   'palmas',
#   'palma sola',
#   'palmares do sul',
#   'santa vitoria do palmar',
#   'nova palma',
#   'santo antonio do palma'],
#  'estrela dalva': ['estrela dalva'],
#  'itamarati de minas': ['itamarati de minas', 'icarai de minas', 'itamarati'],
#  'argirita': ['argirita'],
#  'itapirucu': ['itapirucu', 'itapiru', 'itirucu', 'itaperucu'],
#  ...}
